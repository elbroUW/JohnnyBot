# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import solve_ivp

sys.path.append("JohnnyBotSimulator.")

from JohnnyClass import JohnnyBot
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# test case
BotA = JohnnyBot()
BotA.initstate = jnp.array([0,10,0,0])
BotA.state = BotA.initstate
        
#set initial estimate to init state
BotA.est_state = BotA.initstate

BotA.est_his = [BotA.est_state]
BotA.state_his = [BotA.state]

BotA.control =jnp.array([0,0])
BotA.dt = .05
BotA.distance_noise_std = 1
BotA.angle_noise_std = 1
BotA.maxspeed = 4
BotA.t_span = (0, 10)   # simulation time span
BotA.kv = .5
BotA.kw = 1.8
BotA.arrow_step = 5
BotA.arrowsize = .5
print(BotA.est_state)
# Out:
# [ 0 10  0  0]

# %%
BotA.runsim2()
# Out:
# [ 1.1089311  10.118343   -0.15992339]
# estimate = [ 1.1089311 10.118343  -1.9242989  0.       ]
# true state =  [ 0 10  0  0]
# time = 0.05
# theta =  0
# Converged in 5 iterations.
# estimate = [ 1.1539276 10.817664   0.8627966  0.2      ]
# true state =  [ 0.2        10.          0.02199079  0.2       ]
# time = 0.1
# theta =  0.02199079
# [-0.4039138   7.3956513  -0.14650954]
# estimate = [-0.4039138   7.3956513  -0.68446445  0.4       ]
# true state =  [ 0.39995164 10.004397   -0.20659676  0.4       ]
# time = 0.15000000000000002
# theta =  -0.20659676
# Converged in 5 iterations.
# estimate = [ 0.5638377   9.655064   -0.86322093  0.5851668 ]
# true state =  [ 0.5811808   9.966414   -0.28145617  0.5851668 ]
# time = 0.2
# theta =  -0.28145617
# Converged in 5 iterations.
# estimate = [ 0.09065719  8.915109   -0.9573648   0.7851668 ]
# true state =  [ 0.7733112  9.910864  -0.3503878  0.7851668]
# time = 0.25
# theta =  -0.3503878
# Converged in 4 iterations.
# estimate = [ 0.31938192 11.992831   -0.46790072  0.9851668 ]
# true state =  [ 0.9611591   9.842212   -0.40651184  0.9851668 ]
# time = 0.3
# theta =  -0.40651184
# Converged in 7 iterations.
# estimate = [ 0.44424272 11.272864   -0.6598752   1.1851668 ]
# true state =  [ 1.1448603   9.76313    -0.50816864  1.1851668 ]
# time = 0.35
# theta =  -0.50816864
# Converged in 5 iterations.
# estimate = [ 1.6219859  11.711352   -0.26349527  1.3851669 ]
# true state =  [ 1.3195877  9.665814  -0.5936964  1.3851669]
# time = 0.39999999999999997
# theta =  -0.5936964
# Converged in 4 iterations.
# estimate = [1.5343246  8.750633   0.14907658 1.5851669 ]
# true state =  [ 1.4853634   9.553928   -0.72373945  1.5851669 ]
# time = 0.44999999999999996
# theta =  -0.72373945
# [ 0.9858915  8.742562  -0.559098 ]
# estimate = [ 0.9858915  8.742562  -1.3542576  1.785167 ]
# true state =  [ 1.6352303   9.42149    -0.89414966  1.785167  ]
# time = 0.49999999999999994
# theta =  -0.89414966
# [1.7024724 7.846465  0.4900758]
# estimate = [ 1.7024724  7.846465  -1.6226048  1.985167 ]
# true state =  [ 1.7604667  9.265554  -0.9237447  1.985167 ]
# time = 0.5499999999999999
# theta =  -0.9237447
# [ 2.753293    9.911666   -0.18135478]
# estimate = [ 2.753293    9.911666   -0.14757198  2.185167  ]
# true state =  [ 1.881034    9.105982   -0.93831146  2.185167  ]
# time = 0.6
# theta =  -0.93831146
# [ 0.7624761  7.72257   -1.0333419]
# estimate = [ 0.7624761   7.72257    -0.00974047  2.3851671 ]
# true state =  [ 1.9992641  8.94467   -1.0907873  2.3851671]
# time = 0.65
# theta =  -1.0907873
# [ 3.2396715  10.3040905   0.01537949]
# estimate = [ 3.2396715 10.3040905 -1.7533404  2.5791702]
# true state =  [ 2.0888522  8.772591  -1.2401396  2.5791702]
# time = 0.7000000000000001
# theta =  -1.2401396
# Converged in 4 iterations.
# estimate = [ 2.0992792   9.151849   -0.76992905  2.7791703 ]
# true state =  [ 2.153785   8.583425  -1.2511265  2.7791703]
# time = 0.7500000000000001
# theta =  -1.2511265
# [1.6475855  8.34182    0.84764296]
# estimate = [1.6475855 8.34182   1.07518   2.9791703]
# true state =  [ 2.2166357  8.393557  -1.343498   2.9791703]
# time = 0.8000000000000002
# theta =  -1.343498
# Converged in 4 iterations.
# estimate = [2.5660052  8.39333    0.05556548 3.1791704 ]
# true state =  [ 2.261705   8.198701  -1.5991858  3.1791704]
# time = 0.8500000000000002
# theta =  -1.5991858
# Converged in 4 iterations.
# estimate = [ 1.238414   9.7618065 -1.0463028  3.3791704]
# true state =  [ 2.2560277  7.9987817 -1.772261   3.3791704]
# time = 0.9000000000000002
# theta =  -1.772261
# Converged in 5 iterations.
# estimate = [ 2.9417505  7.57735   -3.5181012  3.5791705]
# true state =  [ 2.2160068  7.802827  -1.8308225  3.5791705]
# time = 0.9500000000000003
# theta =  -1.8308225
# Converged in 5 iterations.
# estimate = [ 3.5819287   9.285909   -0.48991668  3.7791705 ]
# true state =  [ 2.1645856  7.60955   -1.6888937  3.7791705]
# time = 1.0000000000000002
# theta =  -1.6888937
# Converged in 7 iterations.
# estimate = [ 2.5045567  7.2311826 -1.601661   3.9791706]
# true state =  [ 2.141021   7.410943  -1.8193065  3.9791706]
# time = 1.0500000000000003
# theta =  -1.8193065
# [1.3946005  8.579215   0.62905353]
# estimate = [ 1.3946005  8.579215  -1.8863133  4.1704865]
# true state =  [ 2.093965   7.2255044 -1.8465369  4.1704865]
# time = 1.1000000000000003
# theta =  -1.8465369
# Converged in 5 iterations.
# estimate = [ 2.4169228  6.6681848 -3.3960834  4.3704863]
# true state =  [ 2.039513   7.0330596 -1.8326435  4.3704863]
# time = 1.1500000000000004
# theta =  -1.8326435
# Converged in 6 iterations.
# estimate = [ 1.1487216  6.6682453 -1.1565962  4.5478034]
# true state =  [ 1.9936118  6.8617864 -1.6996632  4.5478034]
# time = 1.2000000000000004
# theta =  -1.6996632
# Converged in 4 iterations.
# estimate = [ 1.8101561  6.225306  -1.9165823  4.716965 ]
# true state =  [ 1.9718728  6.6940274 -1.7522945  4.716965 ]
# time = 1.2500000000000004
# theta =  -1.7522945
# [3.686842  7.414659  1.5261037]
# estimate = [ 3.686842   7.414659  -2.4131987  4.8790436]
# true state =  [ 1.942617   6.534611  -1.7466412  4.8790436]
# time = 1.3000000000000005
# theta =  -1.7466412
# Converged in 5 iterations.
# estimate = [ 1.09832    6.223486  -0.7543872  5.0790434]
# true state =  [ 1.907629   6.3376956 -1.7123541  5.0790434]
# time = 1.3500000000000005
# theta =  -1.7123541
# [ 1.7415382   4.632523   -0.29025084]
# estimate = [ 1.7415382  4.632523  -1.3036981  5.237035 ]
# true state =  [ 1.8853387  6.1812844 -1.8015522  5.237035 ]
# time = 1.4000000000000006
# theta =  -1.8015522
# Converged in 5 iterations.
# estimate = [ 2.5794947   6.616108   -0.94203025  5.360761  ]
# true state =  [ 1.8570408  6.0608373 -1.8579543  5.360761 ]
# time = 1.4500000000000006
# theta =  -1.8579543
# [ 1.1211911  3.0579257 -0.5562341]
# estimate = [ 1.1211911  3.0579257 -2.2543526  5.5382905]
# true state =  [ 1.8067596  5.8905773 -1.9480009  5.5382905]
# time = 1.5000000000000007
# theta =  -1.9480009
# Converged in 7 iterations.
# estimate = [ 1.5864207  6.0048337 -3.4062328  5.619715 ]
# true state =  [ 1.776769   5.814877  -1.9181097  5.619715 ]
# time = 1.5500000000000007
# theta =  -1.9181097
# [1.9945291 6.5058975 2.2725575]
# estimate = [ 1.9945291  6.5058975 -1.4855244  5.7749867]
# true state =  [ 1.7239189  5.6688766 -1.7761664  5.7749867]
# time = 1.6000000000000008
# theta =  -1.7761664
# [ 3.3600175   5.0799026  -0.29880747]
# estimate = [ 3.3600175  5.0799026 -2.1469357  5.945106 ]
# true state =  [ 1.6892266  5.502332  -1.8106138  5.945106 ]
# time = 1.6500000000000008
# theta =  -1.8106138
# Converged in 4 iterations.
# estimate = [ 1.860364   7.3178053 -1.5149462  6.0973706]
# true state =  [ 1.65306    5.3544254 -1.8113546  6.0973706]
# time = 1.7000000000000008
# theta =  -1.8113546
# [ 2.870952   6.618335  -1.7690582]
# estimate = [ 2.870952  6.618335 -3.419651  6.286135]
# true state =  [ 1.6080878  5.1710963 -1.8387867  6.286135 ]
# time = 1.7500000000000009
# theta =  -1.8387867
# [ 2.407485   6.9502206 -0.9490108]
# estimate = [ 2.407485   6.9502206 -2.3234406  6.4664903]
# true state =  [ 1.5603309  4.997179  -1.7092259  6.4664903]
# time = 1.800000000000001
# theta =  -1.7092259
# [1.3569757  6.4682984  0.49193367]
# estimate = [ 1.3569757   6.4682984  -0.92188025  6.6503744 ]
# true state =  [ 1.534957   4.815054  -1.6714989  6.6503744]
# time = 1.850000000000001
# theta =  -1.6714989
# Converged in 4 iterations.
# estimate = [ 1.3240802  6.3675556 -2.3030849  6.815602 ]
# true state =  [ 1.5183463  4.6506634 -1.7485124  6.815602 ]
# time = 1.900000000000001
# theta =  -1.7485124
# [ 1.7787384   3.5095499  -0.40131426]
# estimate = [ 1.7787384   3.5095499  -0.49981928  6.978196  ]
# true state =  [ 1.4896026  4.49063   -1.7010581  6.978196 ]
# time = 1.950000000000001
# theta =  -1.7010581
# Converged in 32 iterations.
# estimate = [ 0.7032577  5.3087177 -2.5107229  7.0765605]
# true state =  [ 1.4768257  4.3930993 -1.8396647  7.0765605]
# time = 2.000000000000001
# theta =  -1.8396647
# Converged in 5 iterations.
# estimate = [ 1.8074377  5.2419977 -3.3586252  7.210438 ]
# true state =  [ 1.4412625  4.264032  -1.7669249  7.210438 ]
# time = 2.0500000000000007
# theta =  -1.7669249
# [ 0.385617    5.6327143  -0.42476112]
# estimate = [ 0.385617   5.6327143 -2.2095606  7.349059 ]
# true state =  [ 1.4142488  4.1280684 -1.6359034  7.349059 ]
# time = 2.1000000000000005
# theta =  -1.6359034
# Converged in 4 iterations.
# estimate = [ 0.9911265  3.1292608 -2.044888   7.4902067]
# true state =  [ 1.4050657  3.98722   -1.5845664  7.4902067]
# time = 2.1500000000000004
# theta =  -1.5845664
# Converged in 8 iterations.
# estimate = [ 1.8394496  3.9971035 -2.9777179  7.5722685]
# true state =  [ 1.4039357  3.9051661 -1.569504   7.5722685]
# time = 2.2
# theta =  -1.569504
# [ 1.8280991  4.959227  -1.8359891]
# estimate = [ 1.8280991  4.959227  -3.725237   7.6822696]
# true state =  [ 1.4040778  3.795165  -1.481698   7.6822696]
# time = 2.25
# theta =  -1.481698
# [1.5289801 3.1371737 1.4171653]
# estimate = [ 1.5289801  3.1371737 -1.0242116  7.8144054]
# true state =  [ 1.4158353  3.6635532 -1.3195838  7.8144054]
# time = 2.3
# theta =  -1.3195838
# [ 0.5182766  4.8362613 -1.0001451]
# estimate = [ 0.5182766  4.8362613 -2.1707907  7.901654 ]
# true state =  [ 1.4375234  3.5790434 -1.4095911  7.901654 ]
# time = 2.3499999999999996
# theta =  -1.4095911
# [ 1.6136117   6.3815813  -0.83555454]
# estimate = [ 1.6136117  6.3815813 -3.2474358  8.0232525]
# true state =  [ 1.4570409  3.459021  -1.3651998  8.0232525]
# time = 2.3999999999999995
# theta =  -1.3651998
# Converged in 4 iterations.
# estimate = [ 3.5145535  3.9180205 -0.8120968  8.187813 ]
# true state =  [ 1.4906361  3.2979262 -1.2365919  8.187813 ]
# time = 2.4499999999999993
# theta =  -1.2365919
# [ 1.5016936  2.7664814 -2.3363843]
# estimate = [ 1.5016936  2.7664814 -2.9457307  8.319397 ]
# true state =  [ 1.533798   3.1736226 -1.37068    8.319397 ]
# time = 2.499999999999999
# theta =  -1.37068
# Converged in 4 iterations.
# estimate = [1.1060616 2.1014595 0.9762087 8.398091 ]
# true state =  [ 1.5494411  3.0964987 -1.2916939  8.398091 ]
# time = 2.549999999999999
# theta =  -1.2916939
# Converged in 5 iterations.
# estimate = [ 3.8928823  3.3881035 -2.9260526  8.45746  ]
# true state =  [ 1.5657969  3.039427  -1.5645285  8.45746  ]
# time = 2.5999999999999988
# theta =  -1.5645285
# [ 2.113475  3.282516 -3.318776]
# estimate = [ 2.113475    3.282516   -0.46569157  8.58648   ]
# true state =  [ 1.5666056  2.9104097 -1.5194708  8.58648  ]
# time = 2.6499999999999986
# theta =  -1.5194708
# [0.14294405 2.5828195  0.54107356]
# estimate = [ 0.14294405  2.5828195  -3.2432399   8.684082  ]
# true state =  [ 1.5716128  2.8129368 -1.6704143  8.684082 ]
# time = 2.6999999999999984
# theta =  -1.6704143
# Converged in 4 iterations.
# estimate = [ 1.5130341  4.4661674 -2.1980288  8.748752 ]
# true state =  [ 1.5651813  2.748588  -1.5248703  8.748752 ]
# time = 2.7499999999999982
# theta =  -1.5248703
# [ 1.8261644  3.915801  -1.5369174]
# estimate = [ 1.8261644  3.915801  -1.5037507  8.866639 ]
# true state =  [ 1.5705935  2.630825  -1.4978172  8.866639 ]
# time = 2.799999999999998
# theta =  -1.4978172
# [0.67932856 1.7093804  0.54226804]
# estimate = [ 0.67932856  1.7093804  -2.2124143   8.974656  ]
# true state =  [ 1.5784695  2.5230954 -1.5431249  8.974656 ]
# time = 2.849999999999998
# theta =  -1.5431249
# Converged in 4 iterations.
# estimate = [ 2.0069344  2.6676526 -2.319284   9.020641 ]
# true state =  [ 1.5797418  2.4771276 -1.519424   9.020641 ]
# time = 2.8999999999999977
# theta =  -1.519424
# [ 1.1054301  2.1295855 -0.0207521]
# estimate = [ 1.1054301  2.1295855 -2.651523   9.104098 ]
# true state =  [ 1.5840273  2.3937805 -1.5101088  9.104098 ]
# time = 2.9499999999999975
# theta =  -1.5101088
# Converged in 3 iterations.
# estimate = [ 1.4301033  1.596729  -1.224764   9.1640835]
# true state =  [ 1.5876654  2.333906  -1.4559351  9.1640835]
# time = 2.9999999999999973
# theta =  -1.4559351
# [ 2.4832122  5.339598  -1.4389927]
# estimate = [ 2.4832122  5.339598  -1.9180007  9.217671 ]
# true state =  [ 1.5938071  2.2806706 -1.5528144  9.217671 ]
# time = 3.049999999999997
# theta =  -1.5528144
# Converged in 4 iterations.
# estimate = [ 1.2735124  1.2463565 -2.4350924  9.364891 ]
# true state =  [ 1.5964543  2.133475  -1.5607433  9.364891 ]
# time = 3.099999999999997
# theta =  -1.5607433
# Converged in 12 iterations.
# estimate = [ 1.1925415   0.61396635 -2.3747106   9.409439  ]
# true state =  [ 1.5969021  2.0889294 -1.5546124  9.409439 ]
# time = 3.149999999999997
# theta =  -1.5546124
# Converged in 5 iterations.
# estimate = [ 1.3757027   0.7951774  -0.06767452  9.442972  ]
# true state =  [ 1.5974448  2.055401  -1.5808415  9.442972 ]
# time = 3.1999999999999966
# theta =  -1.5808415
# Converged in 4 iterations.
# estimate = [ 2.8905878  2.9724004 -3.8426173  9.482697 ]
# true state =  [ 1.5970458  2.0156786 -1.8103254  9.482697 ]
# time = 3.2499999999999964
# theta =  -1.8103254
# Converged in 5 iterations.
# estimate = [ 0.07654575  1.112019   -3.2647123   9.58635   ]
# true state =  [ 1.5724543  1.914984  -1.6752915  9.58635  ]
# time = 3.2999999999999963
# theta =  -1.6752915
# Converged in 5 iterations.
# estimate = [ 1.7443945  4.695202  -1.23177    9.614217 ]
# true state =  [ 1.5695478  1.8872697 -1.5290245  9.614217 ]
# time = 3.349999999999996
# theta =  -1.5290245
# Converged in 7 iterations.
# estimate = [ 1.6741124  3.057699  -2.0108347  9.739436 ]
# true state =  [ 1.5747769  1.7621596 -1.5915519  9.739436 ]
# time = 3.399999999999996
# theta =  -1.5915519
# [ 1.5017933  2.4307022 -0.8754676]
# estimate = [ 1.5017933  2.4307022 -1.856756   9.826586 ]
# true state =  [ 1.5729681  1.6750284 -1.597032   9.826586 ]
# time = 3.4499999999999957
# theta =  -1.597032
# Converged in 4 iterations.
# estimate = [ 2.872943   2.6384537 -2.3821597  9.898016 ]
# true state =  [ 1.5710943  1.6036226 -1.6211048  9.898016 ]
# time = 3.4999999999999956
# theta =  -1.6211048
# Converged in 5 iterations.
# estimate = [ 1.424758   0.4277558 -0.7807929  9.995533 ]
# true state =  [ 1.5661904  1.5062292 -1.6225948  9.995533 ]
# time = 3.5499999999999954
# theta =  -1.6225948
# [ 1.8664815  2.92558   -1.4287584]
# estimate = [ 1.8664815  2.92558   -2.5393689 10.032722 ]
# true state =  [ 1.5642649  1.4690894 -1.8088167 10.032722 ]
# time = 3.599999999999995
# theta =  -1.8088167
# Converged in 6 iterations.
# estimate = [ 1.3477764   2.3714867  -0.59602225 10.119479  ]
# true state =  [ 1.5438094  1.3847786 -1.7727547 10.119479 ]
# time = 3.649999999999995
# theta =  -1.7727547
# Converged in 4 iterations.
# estimate = [ 2.3329556  3.0170727 -0.5606711 10.187673 ]
# true state =  [ 1.5301307  1.3179716 -1.9069967 10.187673 ]
# time = 3.699999999999995
# theta =  -1.9069967
# Converged in 31 iterations.
# estimate = [ 0.47497466  0.83493257 -3.2885075  10.283019  ]
# true state =  [ 1.4986758  1.2279634 -2.0571475 10.283019 ]
# time = 3.7499999999999947
# theta =  -2.0571475
# Converged in 4 iterations.
# estimate = [ 0.94762254  1.3941354  -3.4526687  10.307034  ]
# true state =  [ 1.4874513  1.2067336 -1.9491034 10.307034 ]
# time = 3.7999999999999945
# theta =  -1.9491034
# Converged in 6 iterations.
# estimate = [ 1.2539922  2.712039  -1.7503369 10.349176 ]
# true state =  [ 1.471886   1.1675708 -1.8334635 10.349176 ]
# time = 3.8499999999999943
# theta =  -1.8334635
# Converged in 5 iterations.
# estimate = [ 1.3100784  1.5561564 -1.573408  10.423874 ]
# true state =  [ 1.4524902  1.0954349 -1.856284  10.423874 ]
# time = 3.899999999999994
# theta =  -1.856284
# Converged in 4 iterations.
# estimate = [ 2.3047748   1.2263348  -0.38353097 10.474729  ]
# true state =  [ 1.4381682  1.0466385 -1.9190269 10.474729 ]
# time = 3.949999999999994
# theta =  -1.9190269
# Converged in 6 iterations.
# estimate = [ 0.85617626  3.4051666   0.82139707 10.539997  ]
# true state =  [ 1.4158964  0.9852879 -2.1232438 10.539997 ]
# time = 3.999999999999994
# theta =  -2.1232438
# Converged in 5 iterations.
# estimate = [ 1.0746136  1.9749792 -2.8009086 10.627776 ]
# true state =  [ 1.3698325  0.9105668 -2.3607109 10.627776 ]
# time = 4.049999999999994
# theta =  -2.3607109
# [-0.47624296 -1.8189707   1.1173457 ]
# estimate = [-0.47624296 -1.8189707  -2.4971526  10.683987  ]
# true state =  [ 1.3299068  0.8710001 -2.294849  10.683987 ]
# time = 4.099999999999993
# theta =  -2.294849
# [ 1.5320997   0.38063157 -1.1897706 ]
# estimate = [ 1.5320997   0.38063157 -4.205763   10.730993  ]
# true state =  [ 1.2987682   0.83578587 -2.5172668  10.730993  ]
# time = 4.149999999999993
# theta =  -2.5172668
# Converged in 4 iterations.
# estimate = [ 0.45126498 -0.09235382  0.29641843 10.77046   ]
# true state =  [ 1.2667464   0.81271553 -2.3995757  10.77046   ]
# time = 4.199999999999993
# theta =  -2.3995757
# Converged in 6 iterations.
# estimate = [ 2.2345734  2.3550856 -2.2374585 10.781976 ]
# true state =  [ 1.2582582   0.80493367 -2.161678   10.781976  ]
# time = 4.249999999999993
# theta =  -2.161678
# Converged in 5 iterations.
# estimate = [ 2.0479374 -0.7200247 -1.7223358 10.863138 ]
# true state =  [ 1.2130432  0.7375323 -2.1700017 10.863138 ]
# time = 4.299999999999993
# theta =  -2.1700017
# Converged in 4 iterations.
# estimate = [-0.7426457  1.3285875 -2.2849798 10.917409 ]
# true state =  [ 1.1824353  0.6927165 -2.3281627 10.917409 ]
# time = 4.3499999999999925
# theta =  -2.3281627
# Converged in 6 iterations.
# estimate = [ 1.1619443   0.09537647 -1.4356666  10.955461  ]
# true state =  [ 1.1562935  0.6650664 -2.2180126 10.955461 ]
# time = 4.399999999999992
# theta =  -2.2180126
# [ 2.0468566  -0.02003456  0.10967988]
# estimate = [ 2.0468566  -0.02003456 -3.8203232  10.984607  ]
# true state =  [ 1.1387192   0.64181453 -2.3641748  10.984607  ]
# time = 4.449999999999992
# theta =  -2.3641748
# Converged in 6 iterations.
# estimate = [ 2.879074   0.7458243 -1.740175  11.035781 ]
# true state =  [ 1.1022462   0.60591906 -2.3039699  11.035781  ]
# time = 4.499999999999992
# theta =  -2.3039699
# [ 2.4605303   0.36748955 -0.61858195]
# estimate = [ 2.4605303   0.36748955 -2.0181506  11.110133  ]
# true state =  [ 1.052487   0.550671  -2.4072845 11.110133 ]
# time = 4.549999999999992
# theta =  -2.4072845
# Converged in 7 iterations.
# estimate = [ 1.9561094   0.06151095 -4.741338   11.172329  ]
# true state =  [ 1.0063196   0.50899535 -2.4950511  11.172329  ]
# time = 4.599999999999992
# theta =  -2.4950511
# [-0.02741194  0.9336405  -0.13385451]
# estimate = [-0.02741194  0.9336405  -3.0908773  11.221256  ]
# true state =  [ 0.9672676   0.47952035 -2.348245   11.221256  ]
# time = 4.6499999999999915
# theta =  -2.348245
# Converged in 4 iterations.
# estimate = [ 1.4247322 -0.4613519 -1.9963052 11.244607 ]
# true state =  [ 0.9508877  0.4628779 -2.208796  11.244607 ]
# time = 4.699999999999991
# theta =  -2.208796
# Converged in 5 iterations.
# estimate = [ 1.7313082  1.6414192 -3.0020492 11.282046 ]
# true state =  [ 0.9285893   0.43280342 -2.3400564  11.282046  ]
# time = 4.749999999999991
# theta =  -2.3400564
# Converged in 4 iterations.
# estimate = [ 0.34455132  1.2368733  -2.6586106  11.341689  ]
# true state =  [ 0.8871013   0.38995427 -2.2843275  11.341689  ]
# time = 4.799999999999991
# theta =  -2.2843275
# Converged in 4 iterations.
# estimate = [-0.32595038  1.472246   -0.6945466  11.373788  ]
# true state =  [ 0.86609215  0.36568552 -2.2108753  11.373788  ]
# time = 4.849999999999991
# theta =  -2.2108753
# [ 2.4730015   0.64474124 -0.9120821 ]
# estimate = [ 2.4730015   0.64474124 -2.2879415  11.411486  ]
# true state =  [ 0.843577    0.33545035 -2.2701283  11.411486  ]
# time = 4.899999999999991
# theta =  -2.2701283
# [ 2.2861261  0.7137853 -1.1186659]
# estimate = [ 2.2861261  0.7137853 -2.0097187 11.475377 ]
# true state =  [ 0.8024496   0.28655583 -2.3240037  11.475377  ]
# time = 4.94999999999999
# theta =  -2.3240037
# [1.5451164  1.8068997  0.03076324]
# estimate = [ 1.5451164  1.8068997 -2.3848274 11.535252 ]
# true state =  [ 0.7614967   0.24287769 -2.3986354  11.535252  ]
# time = 4.99999999999999
# theta =  -2.3986354
# Converged in 5 iterations.
# estimate = [ 3.1153948  2.3303585 -1.7267584 11.594687 ]
# true state =  [ 0.7177236   0.20267092 -2.3890438  11.594687  ]
# time = 5.04999999999999
# theta =  -2.3890438
# [ 0.04192329 -0.02805863  0.96687096]
# estimate = [ 0.04192329 -0.02805863 -1.1773434  11.691951  ]
# true state =  [ 0.6467263   0.13619128 -2.4585783  11.691951  ]
# time = 5.09999999999999
# theta =  -2.4585783
# Converged in 4 iterations.
# estimate = [ 2.2086303  0.9053569 -2.3613548 11.693212 ]
# true state =  [ 0.6457481   0.13539532 -2.688444   11.693212  ]
# time = 5.14999999999999
# theta =  -2.688444
# Converged in 8 iterations.
# estimate = [ 0.8006961  -0.86597145 -3.2127843  11.752886  ]
# true state =  [ 0.59209615  0.1092698  -2.7236528  11.752886  ]
# time = 5.1999999999999895
# theta =  -2.7236528
# [0.27520403 1.3465104  1.7414582 ]
# estimate = [ 0.27520403  1.3465104  -3.4388213  11.7823715 ]
# true state =  [ 0.56514865  0.09730232 -2.7914546  11.7823715 ]
# time = 5.249999999999989
# theta =  -2.7914546
# Converged in 6 iterations.
# estimate = [ 0.9291782   0.08863517 -2.0959597  11.8167305 ]
# true state =  [ 0.5328747   0.08551635 -2.6414769  11.8167305 ]
# time = 5.299999999999989
# theta =  -2.6414769
# [0.4624414  0.70578235 0.6977823 ]
# estimate = [ 0.4624414   0.70578235 -2.6629624  11.840065  ]
# true state =  [ 0.5123977   0.07432663 -2.7270246  11.840065  ]
# time = 5.349999999999989
# theta =  -2.7270246
# Converged in 5 iterations.
# estimate = [ 0.27632213 -0.30620906 -2.9959111  11.861159  ]
# true state =  [ 0.49308988  0.06582978 -2.6809328  11.861159  ]
# time = 5.399999999999989
# theta =  -2.6809328
# Converged in 4 iterations.
# estimate = [-1.9955593 -1.4248265 -2.8759847 11.87147  ]
# true state =  [ 0.4838534   0.06124598 -2.7693434  11.87147   ]
# time = 5.449999999999989
# theta =  -2.7693434
# Converged in 5 iterations.
# estimate = [ 0.13988082  1.0487753  -2.7570152  11.932771  ]
# true state =  [ 0.42675135  0.03895031 -3.0201862  11.932771  ]
# time = 5.4999999999999885
# theta =  -3.0201862
# Converged in 4 iterations.
# estimate = [ 1.0027399  1.6905313 -3.8022423 11.959222 ]
# true state =  [ 0.4004945  0.0357468 -2.9253597 11.959222 ]
# time = 5.549999999999988
# theta =  -2.9253597
# [ 0.04345021  0.5011207  -0.27608532]
# estimate = [ 0.04345021  0.5011207  -4.0606084  12.008361  ]
# true state =  [ 0.35250008  0.025204   -2.7727127  12.008361  ]
# time = 5.599999999999988
# theta =  -2.7727127
# [-0.81801784 -1.6514529   1.0404824 ]
# estimate = [-0.81801784 -1.6514529  -2.329546   12.020936  ]
# true state =  [ 0.34077096  0.02066981 -2.5564137  12.020936  ]
# time = 5.649999999999988
# theta =  -2.5564137
# [-0.9076348 -2.5542936 -0.8003973]
# estimate = [-0.9076348 -2.5542936 -2.1483943 12.06701  ]
# true state =  [ 3.0236337e-01 -4.7789030e-03 -2.8122611e+00  1.2067010e+01]
# time = 5.699999999999988
# theta =  -2.812261
# [ 1.1743432  1.5995955 -0.6257286]
# estimate = [ 1.1743432  1.5995955 -1.5665916 12.134779 ]
# true state =  [ 0.23823637 -0.02669611 -3.0737486  12.134779  ]
# time = 5.749999999999988
# theta =  -3.0737486
# [ 1.5394713 -0.9288835 -1.4154718]
# estimate = [ 1.5394713 -0.9288835 -2.3773026 12.184388 ]
# true state =  [ 0.18874085 -0.03005925 -3.131122   12.184388  ]
# time = 5.799999999999987
# theta =  -3.131122
# [ 0.99792236  1.443701   -1.2937777 ]
# estimate = [ 0.99792236  1.443701   -2.2164457  12.229338  ]
# true state =  [ 0.14379337 -0.03052989 -3.2487693  12.229338  ]
# time = 5.849999999999987
# theta =  -3.2487693
# Converged in 4 iterations.
# estimate = [-1.5817775  1.7649827 -4.455513  12.273213 ]
# true state =  [ 0.10016944 -0.02583644 -3.245094   12.273213  ]
# time = 5.899999999999987
# theta =  -3.245094
# Converged in 5 iterations.
# estimate = [ 0.8400616  1.5602874 -2.3136024 12.332465 ]
# true state =  [ 0.04123502 -0.01971477 -3.4851923  12.332465  ]
# time = 5.949999999999987
# theta =  -3.4851923
# Converged in 4 iterations.
# estimate = [ 0.85172623 -1.6639119  -3.5897405  12.376767  ]
# true state =  [-4.7699735e-04 -4.7905380e-03 -3.4627903e+00  1.2376767e+01]
# time = 5.999999999999987
# theta =  -3.4627903
# Converged in 4 iterations.
# estimate = [ 0.30175257  0.04409352 -2.6261234  12.423498  ]
# true state =  [-4.4817969e-02  9.9625476e-03 -3.5212491e+00  1.2423498e+01]
# time = 6.0499999999999865
# theta =  -3.521249
# Converged in 4 iterations.
# estimate = [-0.05791167  2.1862216  -3.2500393  12.431122  ]
# true state =  [-0.05189901  0.01278799 -3.5545826  12.431122  ]
# time = 6.099999999999986
# theta =  -3.5545826
# Converged in 5 iterations.
# estimate = [-0.27293202  0.89572203 -4.1706634  12.485797  ]
# true state =  [-0.10197694  0.03473166 -3.4010673  12.485797  ]
# time = 6.149999999999986
# theta =  -3.4010673
# Converged in 5 iterations.
# estimate = [ 0.5634538   0.96952397 -2.1542852  12.509207  ]
# true state =  [-0.12460283  0.04073791 -3.14046    12.509207  ]
# time = 6.199999999999986
# theta =  -3.14046
# Converged in 6 iterations.
# estimate = [ 1.3253785  2.8454325 -4.387765  12.537241 ]
# true state =  [-0.15263692  0.04070616 -3.135327   12.537241  ]
# time = 6.249999999999986
# theta =  -3.135327
# [ 0.15238553  0.93166304 -0.4126109 ]
# estimate = [ 0.15238553  0.93166304 -2.039205   12.615715  ]
# true state =  [-0.23110956  0.04021448 -2.9210317  12.615715  ]
# time = 6.299999999999986
# theta =  -2.9210317
# [-1.7607719  -0.10728972  1.8912653 ]
# estimate = [-1.7607719  -0.10728972 -2.957937   12.639317  ]
# true state =  [-0.2541389  0.0350511 -2.8934665 12.639317 ]
# time = 6.349999999999985
# theta =  -2.8934665
# Converged in 4 iterations.
# estimate = [ 0.6210273  1.5461948 -4.3520184 12.683417 ]
# true state =  [-0.29688922  0.02422044 -2.621775   12.683417  ]
# time = 6.399999999999985
# theta =  -2.621775
# Converged in 5 iterations.
# estimate = [-0.5418345   0.99877363 -1.831826   12.725074  ]
# true state =  [-3.3304310e-01  3.5288520e-03 -2.4058385e+00  1.2725074e+01]
# time = 6.449999999999985
# theta =  -2.4058385
# Converged in 4 iterations.
# estimate = [ 1.3233787  2.2267857 -1.810049  12.753481 ]
# true state =  [-0.35410193 -0.01553641 -2.3376098  12.753481  ]
# time = 6.499999999999985
# theta =  -2.3376098
# Converged in 4 iterations.
# estimate = [-0.91313475 -0.59187365 -3.0733905  12.818239  ]
# true state =  [-0.39903438 -0.0621708  -2.3643367  12.818239  ]
# time = 6.549999999999985
# theta =  -2.3643367
# Converged in 7 iterations.
# estimate = [-1.712561    0.03060519 -1.2452875  12.845444  ]
# true state =  [-0.4184268  -0.08124997 -2.60146    12.845444  ]
# time = 6.5999999999999845
# theta =  -2.60146
# Converged in 5 iterations.
# estimate = [-0.9403749  1.7677754 -4.2932987 12.888265 ]
# true state =  [-0.4551517 -0.1032706 -2.4909923 12.888265 ]
# time = 6.649999999999984
# theta =  -2.4909923
# [-1.2626094  -2.0280325   0.31632796]
# estimate = [-1.2626094 -2.0280325 -1.129327  12.938323 ]
# true state =  [-0.49498412 -0.13358912 -2.7674544  12.938323  ]
# time = 6.699999999999984
# theta =  -2.7674544
# Converged in 6 iterations.
# estimate = [-1.7556266   0.85095423 -1.1563401  12.998047  ]
# true state =  [-0.55057645 -0.15541643 -2.5745604  12.998047  ]
# time = 6.749999999999984
# theta =  -2.5745604
# Converged in 4 iterations.
# estimate = [ 0.03994753 -0.45220563 -1.8148606  13.046822  ]
# true state =  [-0.59171784 -0.18161482 -2.5111098  13.046822  ]
# time = 6.799999999999984
# theta =  -2.5111098
# [-1.1985623  1.3051825  0.9222506]
# estimate = [-1.1985623  1.3051825 -3.6194222 13.05817  ]
# true state =  [-0.60088503 -0.18830554 -2.7639575  13.05817   ]
# time = 6.849999999999984
# theta =  -2.7639575
# Converged in 4 iterations.
# estimate = [ 0.55457705  1.3493311  -2.0125332  13.10247   ]
# true state =  [-0.6420641  -0.20464016 -2.5127256  13.10247   ]
# time = 6.8999999999999835
# theta =  -2.5127256
# Converged in 4 iterations.
# estimate = [-0.12442549  0.6722079  -1.8447566  13.138942  ]
# true state =  [-0.67155826 -0.22609365 -2.5080652  13.138942  ]
# time = 6.949999999999983
# theta =  -2.5080652
# [-0.5784581  -1.5167296   0.10339292]
# estimate = [-0.5784581 -1.5167296 -0.8737433 13.156033 ]
# true state =  [-0.68533236 -0.23621118 -2.4669363  13.156033  ]
# time = 6.999999999999983
# theta =  -2.4669363
# [-0.33391395 -0.5295941   0.36953044]
# estimate = [-0.33391395 -0.5295941  -1.4497449  13.196615  ]
# true state =  [-0.71702397 -0.26156008 -2.2797198  13.196615  ]
# time = 7.049999999999983
# theta =  -2.2797198
# [-1.1749241  -0.29223025  0.3896964 ]
# estimate = [-1.1749241  -0.29223025 -1.5401225  13.212267  ]
# true state =  [-0.72721356 -0.2734408  -2.0585008  13.212267  ]
# time = 7.099999999999983
# theta =  -2.0585008
# [-1.7816222  -2.2049499   0.90256613]
# estimate = [-1.7816222 -2.2049499 -1.5480965 13.242535 ]
# true state =  [-0.74139714 -0.3001799  -1.8979499  13.242535  ]
# time = 7.149999999999983
# theta =  -1.8979499
# Converged in 5 iterations.
# estimate = [-0.33985636 -1.9560668  -1.9330071  13.313404  ]
# true state =  [-0.764171   -0.36729056 -1.6784141  13.313404  ]
# time = 7.199999999999982
# theta =  -1.6784141
# Converged in 4 iterations.
# estimate = [-0.89160216 -1.74164    -2.5117612  13.363038  ]
# true state =  [-0.7695022 -0.4166377 -1.944041  13.363038 ]
# time = 7.249999999999982
# theta =  -1.944041
# Converged in 5 iterations.
# estimate = [ 0.87129676  0.572456   -3.3499165  13.411953  ]
# true state =  [-0.7873385  -0.46218473 -2.184681   13.411953  ]
# time = 7.299999999999982
# theta =  -2.184681
# [-0.3301043  2.0049193 -1.342207 ]
# estimate = [-0.3301043  2.0049193 -2.4044483 13.438016 ]
# true state =  [-0.80235213 -0.48348922 -2.1136155  13.438016  ]
# time = 7.349999999999982
# theta =  -2.1136155
# [ 0.53224105 -0.198348   -1.3519516 ]
# estimate = [ 0.53224105 -0.198348   -3.6509876  13.488813  ]
# true state =  [-0.8285918  -0.52698517 -2.0239003  13.488813  ]
# time = 7.399999999999982
# theta =  -2.0239003
# [ 0.19310293  1.4307166  -0.9485715 ]
# estimate = [ 0.19310293  1.4307166  -2.5435677  13.503014  ]
# true state =  [-0.834808   -0.53975224 -2.0101597  13.503014  ]
# time = 7.4499999999999815
# theta =  -2.0101597
# [-0.7722659  2.1009798  1.2219799]
# estimate = [-0.7722659  2.1009798 -3.557888  13.539105 ]
# true state =  [-0.8501603  -0.57241654 -1.9346846  13.539105  ]
# time = 7.499999999999981
# theta =  -1.9346846
# Converged in 4 iterations.
# estimate = [ 0.18135202  1.5482577  -0.8145521  13.595066  ]
# true state =  [-0.8700772 -0.6247127 -1.7241443 13.595066 ]
# time = 7.549999999999981
# theta =  -1.7241443
# Converged in 4 iterations.
# estimate = [-0.83034253 -0.17891014 -3.2747471  13.634037  ]
# true state =  [-0.8760299 -0.6632265 -1.8027005 13.634037 ]
# time = 7.599999999999981
# theta =  -1.8027005
# Converged in 4 iterations.
# estimate = [-1.9593385  0.5196541 -2.0064147 13.655272 ]
# true state =  [-0.88091034 -0.683893   -2.0543602  13.655272  ]
# time = 7.649999999999981
# theta =  -2.0543602
# Converged in 5 iterations.
# estimate = [ 0.10536607 -0.16334736 -3.0854235  13.705949  ]
# true state =  [-0.90447193 -0.7287595  -1.8971153  13.705949  ]
# time = 7.699999999999981
# theta =  -1.8971153
# Converged in 192 iterations.
# estimate = [ 0.29090354 -0.32585347 -0.31804156 13.710809  ]
# true state =  [-0.9060297 -0.7333626 -1.9919828 13.710809 ]
# time = 7.7499999999999805
# theta =  -1.9919828
# Converged in 6 iterations.
# estimate = [-2.2932007   0.95489097 -2.4724166  13.721729  ]
# true state =  [-0.9104944 -0.7433286 -1.7563962 13.721729 ]
# time = 7.79999999999998
# theta =  -1.7563962
# Converged in 5 iterations.
# estimate = [-1.2874297  -3.1763997  -0.24837875 13.783831  ]
# true state =  [-0.9219544  -0.80436367 -1.5693895  13.783831  ]
# time = 7.84999999999998
# theta =  -1.5693895
# Converged in 4 iterations.
# estimate = [-0.56837416 -1.6072496  -2.4223342  13.869515  ]
# true state =  [-0.9218339  -0.89004827 -1.4403206  13.869515  ]
# time = 7.89999999999998
# theta =  -1.4403206
# Converged in 4 iterations.
# estimate = [-0.9926403 -1.0891523 -1.5553985 13.912135 ]
# true state =  [-0.9162888 -0.9323057 -1.6770171 13.912135 ]
# time = 7.94999999999998
# theta =  -1.6770171
# [-0.63072395  1.3225726  -0.65843666]
# estimate = [-0.63072395  1.3225726  -1.6413878  13.948976  ]
# true state =  [-0.9201947 -0.9689388 -1.462176  13.948976 ]
# time = 7.99999999999998
# theta =  -1.462176
# Converged in 5 iterations.
# estimate = [-2.4365506 -3.8219943 -0.7043218 13.985607 ]
# true state =  [-0.9162236 -1.0053546 -1.4157735 13.985607 ]
# time = 8.04999999999998
# theta =  -1.4157735
# Converged in 5 iterations.
# estimate = [-0.8896835  -0.48917395 -1.0781754  14.098922  ]
# true state =  [-0.8987275 -1.1173106 -1.2620918 14.098922 ]
# time = 8.09999999999998
# theta =  -1.2620918
# Converged in 4 iterations.
# estimate = [ 0.36642826 -0.20702028 -0.9972782  14.124304  ]
# true state =  [-0.89101565 -1.1414932  -1.1198119  14.124304  ]
# time = 8.14999999999998
# theta =  -1.1198119
# Converged in 4 iterations.
# estimate = [-2.378264   2.4494295 -0.8919655 14.134826 ]
# true state =  [-0.8864298 -1.1509628 -1.3590839 14.134826 ]
# time = 8.199999999999982
# theta =  -1.3590839
# Converged in 6 iterations.
# estimate = [ 1.9087963   0.07498443 -0.6787229  14.220178  ]
# true state =  [-0.86849445 -1.2344087  -1.3508195  14.220178  ]
# time = 8.249999999999982
# theta =  -1.3508195
# Converged in 5 iterations.
# estimate = [-1.2159603  -0.62219054 -1.5380683  14.267935  ]
# true state =  [-0.8580736 -1.2810147 -1.5689441 14.267935 ]
# time = 8.299999999999983
# theta =  -1.5689441
# [-0.5835346  -2.6669939   0.09318613]
# estimate = [-0.5835346  -2.6669939  -0.10489142 14.302082  ]
# true state =  [-0.85801035 -1.3151621  -1.3879522  14.302082  ]
# time = 8.349999999999984
# theta =  -1.3879522
# Converged in 5 iterations.
# estimate = [ 0.6039621  -0.53172326 -2.4586067  14.370335  ]
# true state =  [-0.84560025 -1.3822765  -1.2565267  14.370335  ]
# time = 8.399999999999984
# theta =  -1.2565267
# Converged in 4 iterations.
# estimate = [ 0.74966806  0.96181107 -2.1700726  14.390451  ]
# true state =  [-0.8393817 -1.4014081 -1.3829643 14.390451 ]
# time = 8.449999999999985
# theta =  -1.3829643
# Converged in 5 iterations.
# estimate = [-0.34563622 -0.04085598 -2.9717226  14.420938  ]
# true state =  [-0.833689  -1.4313583 -1.3886161 14.420938 ]
# time = 8.499999999999986
# theta =  -1.3886161
# Converged in 15 iterations.
# estimate = [-0.8693786 -1.2269341 -1.1908323 14.429639 ]
# true state =  [-0.83211255 -1.4399154  -1.1105717  14.429639  ]
# time = 8.549999999999986
# theta =  -1.1105717
# [-0.10262153 -0.99677026 -0.46213606]
# estimate = [-0.10262153 -0.99677026 -1.6605039  14.467232  ]
# true state =  [-0.8154156 -1.473597  -0.9175066 14.467232 ]
# time = 8.599999999999987
# theta =  -0.9175066
# Converged in 69 iterations.
# estimate = [ 0.8065137 -2.6012485 -0.7812656 14.492283 ]
# true state =  [-0.8001896 -1.4934897 -0.6359229 14.492283 ]
# time = 8.649999999999988
# theta =  -0.6359229
# [-1.3118031 -1.2325997  0.5900444]
# estimate = [-1.3118031 -1.2325997  1.576268  14.560369 ]
# true state =  [-0.7454134  -1.533927   -0.39717883 14.560369  ]
# time = 8.699999999999989
# theta =  -0.39717883
# Converged in 6 iterations.
# estimate = [-1.3288685  1.6035262  1.3983184 14.60537  ]
# true state =  [-0.7039156 -1.5513341 -0.4711578 14.60537  ]
# time = 8.74999999999999
# theta =  -0.4711578
# Converged in 4 iterations.
# estimate = [-1.3815205e+00 -1.4717109e+00 -1.4295101e-02  1.4657434e+01]
# true state =  [-0.65752363 -1.5749673  -0.67609745 14.657434  ]
# time = 8.79999999999999
# theta =  -0.67609745
# [ 0.3041237  -3.8703494  -0.05005145]
# estimate = [ 0.3041237 -3.8703494 -0.8173724 14.707898 ]
# true state =  [-0.6181609 -1.6065451 -0.6012811 14.707898 ]
# time = 8.84999999999999
# theta =  -0.6012811
# Converged in 7 iterations.
# estimate = [ 0.14181618 -1.3327873  -1.898904   14.8049555 ]
# true state =  [-0.5381266  -1.6614501  -0.37928843 14.8049555 ]
# time = 8.899999999999991
# theta =  -0.37928843
# [ 0.07612558 -2.7016988  -0.85719305]
# estimate = [ 0.07612558 -2.7016988  -0.23347256 14.838463  ]
# true state =  [-0.50700027 -1.6738567  -0.6229615  14.838463  ]
# time = 8.949999999999992
# theta =  -0.6229615
# [-1.1522772  -0.88745135  1.2601607 ]
# estimate = [-1.1522772  -0.88745135 -1.8244934  14.906033  ]
# true state =  [-0.4521236 -1.7132796 -0.4580421 14.906033 ]
# time = 8.999999999999993
# theta =  -0.4580421
# Converged in 6 iterations.
# estimate = [ 0.14918484  0.34994277 -0.9199022  14.942393  ]
# true state =  [-0.41951135 -1.7293578  -0.2347719  14.942393  ]
# time = 9.049999999999994
# theta =  -0.2347719
# Converged in 8 iterations.
# estimate = [-1.3300664  -2.2207024  -0.77679324 14.951903  ]
# true state =  [-0.41026184 -1.7315701  -0.32962072 14.951903  ]
# time = 9.099999999999994
# theta =  -0.32962072
# [-0.7124038 -0.673291  -1.2201521]
# estimate = [-0.7124038 -0.673291   0.5691091 15.016617 ]
# true state =  [-0.34903193 -1.752517   -0.1669052  15.016617  ]
# time = 9.149999999999995
# theta =  -0.1669052
# Converged in 7 iterations.
# estimate = [-0.4924949   0.23992994 -0.45769498 15.041122  ]
# true state =  [-0.32486686 -1.7565881  -0.14997885 15.041122  ]
# time = 9.199999999999996
# theta =  -0.14997885
# Converged in 5 iterations.
# estimate = [ 0.17242478 -1.0660722  -1.6710681  15.054818  ]
# true state =  [-0.31132486 -1.7586344  -0.14958628 15.054818  ]
# time = 9.249999999999996
# theta =  -0.14958628
# Converged in 321 iterations.
# estimate = [-0.5796221  -2.0072072  -0.32346722 15.081817  ]
# true state =  [-0.2846282  -1.762658   -0.40887368 15.081817  ]
# time = 9.299999999999997
# theta =  -0.40887368
# [-0.8323646  -0.6603934  -0.23453274]
# estimate = [-0.8323646  -0.6603934  -0.22565123 15.1340475 ]
# true state =  [-0.2367031 -1.7834237 -0.263691  15.1340475]
# time = 9.349999999999998
# theta =  -0.263691
# Converged in 4 iterations.
# estimate = [-0.28662163 -0.30234694  0.5951469  15.16061   ]
# true state =  [-0.21105824 -1.7903472  -0.1830194  15.16061   ]
# time = 9.399999999999999
# theta =  -0.1830194
# Converged in 4 iterations.
# estimate = [ 0.49541867 -0.90046257  0.15758362 15.171025  ]
# true state =  [-0.20081688 -1.7922428  -0.16349438 15.171025  ]
# time = 9.45
# theta =  -0.16349438
# Converged in 20 iterations.
# estimate = [ 0.9681832  -1.289804   -0.93975186 15.196719  ]
# true state =  [-1.7546575e-01 -1.7964249e+00  8.9632720e-03  1.5196719e+01]
# time = 9.5
# theta =  0.008963272
# Converged in 4 iterations.
# estimate = [ 0.5324202 -1.6277946 -1.1032171 15.237038 ]
# true state =  [-0.13514853 -1.7960634  -0.27262193 15.237038  ]
# time = 9.55
# theta =  -0.27262193
# Converged in 4 iterations.
# estimate = [-2.418325   -2.9899776   0.34023684 15.279854  ]
# true state =  [-9.3913436e-02 -1.8075920e+00 -3.5105944e-03  1.5279854e+01]
# time = 9.600000000000001
# theta =  -0.0035105944
# Converged in 4 iterations.
# estimate = [ 0.9444516 -1.2990252  2.143688  15.375993 ]
# true state =  [ 2.2247434e-03 -1.8079295e+00  4.6031650e-02  1.5375993e+01]
# time = 9.650000000000002
# theta =  0.04603165
# [-0.47002617 -1.5216917   0.9896528 ]
# estimate = [-0.47002617 -1.5216917   0.34193286 15.416144  ]
# true state =  [ 0.04233392 -1.8060819   0.05104974 15.416144  ]
# time = 9.700000000000003
# theta =  0.051049743
# Converged in 4 iterations.
# estimate = [ 1.0715162  0.9464228  0.4311672 15.45596  ]
# true state =  [ 0.0820978 -1.8040502  0.1346846 15.45596  ]
# time = 9.750000000000004
# theta =  0.1346846
# Converged in 4 iterations.
# estimate = [ 0.7252553 -0.9991156  1.4720421 15.491701 ]
# true state =  [ 0.11751506 -1.799251   -0.12174995 15.491701  ]
# time = 9.800000000000004
# theta =  -0.12174995
# Converged in 6 iterations.
# estimate = [ 0.31582478 -2.4237034  -0.02379676 15.522566  ]
# true state =  [ 0.14815149 -1.8029995  -0.05635143 15.522566  ]
# time = 9.850000000000005
# theta =  -0.05635143
# Converged in 6 iterations.
# estimate = [ 0.56482375 -1.8759183   0.19344693 15.583671  ]
# true state =  [ 0.20915934 -1.8064411   0.09882387 15.583671  ]
# time = 9.900000000000006
# theta =  0.09882387
# Converged in 4 iterations.
# estimate = [ 0.21874753 -1.7146046   1.0850095  15.632648  ]
# true state =  [ 0.25789803 -1.8016088   0.24910656 15.632648  ]
# time = 9.950000000000006
# theta =  0.24910656

# %%
BotA.plotTraj()

# %%
BotA.plotXY()
