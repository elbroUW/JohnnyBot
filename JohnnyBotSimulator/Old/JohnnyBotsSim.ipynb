# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import solve_ivp

sys.path.append("JohnnyBotSimulator.")

from JohnnyBotSimulator.Old.JohnnyClass import JohnnyBot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_36624\2103599935.py in <module>
#      12 sys.path.append("JohnnyBotSimulator.")
#      13
# ---> 14 from JohnnyBotSimulator.Old.JohnnyClass import JohnnyBot
#
# ModuleNotFoundError: No module named 'JohnnyBotSimulator'

# %%
# test case
BotA = JohnnyBot()
BotA.initstate = jnp.array([-10,-10,2.1,0])
BotA.state = BotA.initstate
        
#set initial estimate to init state
BotA.est_state = BotA.initstate
BotA.goalstate = jnp.array([10,10,0,0])

BotA.est_his = [BotA.est_state]
BotA.state_his = [BotA.state]

BotA.control =jnp.array([0,0])
BotA.dt = .1
BotA.distance_noise_std = .5
BotA.angle_noise_std = .7
BotA.maxspeed = 4
BotA.t_span = (0, 15)   # simulation time span
BotA.kv = .5
BotA.kw = 1.8
BotA.arrow_step = 5
BotA.arrowsize = .5
print(BotA.est_state)
# Out:
# [-10.  -10.    2.1   0. ]

# %%
BotA.runsim2()
# Out:
# [-10.059325    -9.864297    -0.85108536]
# estimate = [-10.059325   -9.864297    2.2229776   0.       ]
# true state =  [-10.  -10.    2.1   0. ]
# time = 0.1
# theta =  2.1
# Converged in 5 iterations.
# estimate = [-10.340375   -9.56806     2.1035318   0.4      ]
# true state =  [-10.201939   -9.6547165   1.8403562   0.4      ]
# time = 0.2
# theta =  1.8403562
# [-10.456607   -9.862393    1.4139563]
# estimate = [-10.456607   -9.862393    2.2282481   0.8      ]
# true state =  [-10.308461   -9.269161    1.5996093   0.8      ]
# time = 0.30000000000000004
# theta =  1.5996093
# [-11.05552     -7.7776318   -0.29448873]
# estimate = [-11.05552    -7.7776318   1.9047148   1.2      ]
# true state =  [-10.319984   -8.869328    1.3372437   1.2      ]
# time = 0.4
# theta =  1.3372437
# Converged in 5 iterations.
# estimate = [-10.612029   -8.822175    1.2342243   1.6      ]
# true state =  [-10.22741    -8.480187    1.1206089   1.6      ]
# time = 0.5
# theta =  1.1206089
# ...

# %%
BotA.plotTraj()

# %%
BotA.plotXY()
