# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
import jax
import jax.numpy as jnp
from jax import jit
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import solve_ivp
from jax.typing import ArrayLike

sys.path.append("JohnnyBotSimulator.")


# Dynamically determine the path to the JohnnyBotSimulator directory
current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))
sys.path.append(parent_dir)

from Dynamics.JohnnyDynamics import JohnnyDynamics
from Controller.JohnnyControl import JohnnyController
from Estimation.PNT_Estimation import PNT_Estimation

import cvxpy as cp

# %%
SCP = JohnnyController()

# %%
def barrier_function(state, r=2):
    x, y, theta, v = state
    return (x-3)**2 + (y-3)**2 - r**2


# linearization of dynamics
def linearize_autodiff3(state, control, func_dynamics): 

    func_x = jit(jax.jacfwd(func_dynamics, argnums=0))
    func_u = jit(jax.jacfwd(func_dynamics, argnums=1))

    A = func_x(state, control)
    B = func_u(state, control)

    return A, B

def lie_derivative(func, vector_field_func, state):
    '''
    func: a function that takes in a state and returns a scalar value.
          i.e., func(state) = scalar
    vector_field_func: a function that takes in a state and returns a
                      vector/matrix. i.e., func(state) = vector/matrix
    state: an array describing the state which is the input to func and
          vector_field_func
    '''

    func_gradx = jax.jacobian(func)
    #func_gradu = jax.jacobian(vector_field_func, argnums=1)
    
    lie = jnp.matmul(func_gradx(state).T, vector_field_func(state))
     
    return lie

def lie_derivative2(func, vector_field_func, state, control):
    '''
    func: a function that takes in a state and returns a scalar value.
          i.e., func(state) = scalar
    vector_field_func: a function that takes in a state and returns a
                      vector/matrix. i.e., func(state) = vector/matrix
    state: an array describing the state which is the input to func and
          vector_field_func
    '''

    func_gradx = jax.jacobian(func)
    #func_gradu = jax.jacobian(vector_field_func, argnums=1)
    state = jnp.array(state)

    lie = jnp.matmul(func_gradx(state).T, vector_field_func(state,control))
     
    return lie

def control_constraint_degree_2(h, dynamics, state, control, class_K_funcs):
    '''
    h: a function that takes in a state and returns a scalar value.
          i.e., h(state) = scalar
    dynamics: the DynamicallyExtendedUnicycle class defined above
    state: an array describing the state which is the input to func and
          vector_field_func
    class_K_funcs: a 2-list of class K function [alpha_func_1, alpha_func_2]

    Compute the coefficients for the CBF/CLF inequality terms, assuming all the terms are moved to the LHS

    Lf2h(z) + LgLfh(z)u + Lfa1h(z) + a2_term


    Returns:
    Lf2h
    LgLfh
    Lfa1h
    a2_term
    '''
    Lfh_func = lambda state: lie_derivative2(h, dynamics.dynamics2, state, control)
    Lfh = lie_derivative2(h, dynamics.dynamics2, state, control)

    alpha1, alpha2 =  class_K_funcs
    alpha1_h_func = lambda state: alpha1(h(state))
    
    Lf2h = lie_derivative2(Lfh_func, dynamics.dynamics2, state, control)
    LgLfh = lie_derivative(Lfh_func, dynamics.control_matrix, state)
    Lfa1h = lie_derivative2(alpha1_h_func, dynamics.dynamics2, state, control)
    a2_term = alpha2(Lfh + alpha1(h(state)))

    return Lf2h, LgLfh, Lfa1h, a2_term


alpha1 = lambda x: 2 * x
alpha2 = lambda x: 2 * x

test_state = jnp.array([-1.0, 2.0, 0.1, 1.0])
test_control = jnp.array([0, 0])


#lie_derivative(barrier_function, dynamics.drift_dynamics, test_state)

lie_derivative2(barrier_function, dynamics.dynamics2, test_state, test_control)
# Out:
# Array(-2.8, dtype=float32)

# %%
SCP.plotter.source= [3,3]
SCP.state0 = jnp.array([-2.0, -2.0, 0, 0])

SCP.states = [SCP.state0]
SCP.controls = [SCP.control]


# Find Initial Trajectory




# Time horizon
MPC_horizon = 20
SCP.tf = 10
time_horizon = int(SCP.tf / SCP.dt)

SCP.time = np.linspace(SCP.t0, SCP.tf, time_horizon)

SCP.desired_states = np.tile(SCP.desired_state, (time_horizon, 1))

# Define optimization variables
us = cp.Variable((2, MPC_horizon - 1))  # Control inputs [x_dot_dot, y_dot_dot]
states = cp.Variable((4, MPC_horizon))  # States [x, y, x_dot, y_dot]

state1 = cp.Parameter(4)
# Define optimization variables

db = cp.Parameter(2)
b = cp.Parameter(1)


As = cp.Parameter((4, 4)) # for later
As.project_and_assign(A)
Bs = cp.Parameter((4, 2)) # for later  
Bs.project_and_assign(B)


# Define Q and R matrices
Q = np.diag([2, 2, 1, 1])  # Penalize position error more than velocity error
R = np.diag([0.1, 0.1])  # Penalize control effort

# Define constraints list
constraints = []

# Initial state constraint
constraints.append(states[:, 0] == state1)

constraints.append(b + (db @ us) >= 0)

# Dynamics constraints
for t in range(MPC_horizon - 1):
    constraints.append(states[:, t + 1] == states[:, t] + (A @ states[:, t] + B @ us[:, t]) * SCP.dt)
    


# Control input constraints
constraints.append(us[0, :] <= SCP.max_acceleration)
constraints.append(us[0, :] >= SCP.min_acceleration)
constraints.append(us[1, :] <= SCP.max_acceleration)
constraints.append(us[1, :] >= SCP.min_acceleration)



# Define the objective function (vectorized)
objective = cp.Minimize(
    cp.sum([cp.quad_form(states[:, t] - SCP.desired_states[t, :], Q) for t in range(MPC_horizon)]) +
    cp.sum([cp.quad_form(us[:, t], R) for t in range(MPC_horizon - 1)])
)

# Solve the optimization problem
prob = cp.Problem(objective, constraints)

# Solve the problem iteratively
for i in range(time_horizon-1):

    new_state = SCP.states[-1]
    new_control = SCP.controls[-1]
    state1.project_and_assign(new_state)
    
    # b CBF constraint
    L2fb, LgLfb, Lfa1b, a2_term = control_constraint_degree_2(barrier_function, dynamics, new_state, new_control, [alpha1, alpha2])
    db.project_and_assign(LgLfb)
    b.project_and_assign(L2fb + Lfa1b + a2_term)
    
    # Solve the optimization problem
    result = prob.solve()

    # Check if the problem was solved successfully
    if prob.status == cp.OPTIMAL:
        print(f"Step {i}: Optimization successful!")
        print("Optimal cost:", result)

        # Append the first state and control input to the trajectories
        print("Optimal initial state trajectory:", states.value[:,0])
        print("Optimal state trajectory:", states.value[:,1])
        SCP.states.append(states.value[:, 1])  # First state in the horizon
        SCP.controls.append(us.value[:, 0])  # First control input in the horizon
    
    else:
        print(f"Step {i}: Optimization failed:", prob.status)
        break

SCP.plot()
# Out:
# Step 0: Optimization successful!
# Optimal cost: 11508.748561168682
# Optimal initial state trajectory: [-2.00000000e+00 -2.00000000e+00  4.54394265e-14  4.49939669e-14]
# Optimal state trajectory: [-2.   -2.    0.02  0.02]
# Step 1: Optimization successful!
# Optimal cost: 11507.579467328504
# Optimal initial state trajectory: [-2.00010473 -2.00010509  0.01959373  0.01959467]
# Optimal state trajectory: [-2.00001333 -2.00001404  0.03918987  0.03919546]
# Step 2: Optimization successful!
# Optimal cost: 11502.120409340376
# Optimal initial state trajectory: [-2.00001333 -2.00001404  0.03918987  0.03919546]
# Optimal state trajectory: [-1.99962143 -1.99962208  0.05918987  0.05919546]
# Step 3: Optimization successful!
# Optimal cost: 11498.019368668392
# Optimal initial state trajectory: [-1.99962143 -1.99962208  0.05918987  0.05919546]
# Optimal state trajectory: [-1.99902953 -1.99903013  0.07918987  0.07919546]
# Step 4: Optimization successful!
# Optimal cost: 11493.566400769192
# Optimal initial state trajectory: [-1.99902953 -1.99903013  0.07918987  0.07919546]
# Optimal state trajectory: [-1.99823763 -1.99823817  0.09918987  0.09919546]
# Step 5: Optimization successful!
# Optimal cost: 11488.76174033867
# Optimal initial state trajectory: [-1.99823763 -1.99823817  0.09918987  0.09919546]
# Optimal state trajectory: [-1.99724573 -1.99724622  0.11918987  0.11919546]
# Step 6: Optimization successful!
# Optimal cost: 11483.60564126795
# Optimal initial state trajectory: [-1.99724573 -1.99724622  0.11918987  0.11919546]
# Optimal state trajectory: [-1.99605383 -1.99605426  0.13918987  0.13919546]
# Step 7: Optimization successful!
# Optimal cost: 11478.098376643406
# Optimal initial state trajectory: [-1.99605383 -1.99605426  0.13918987  0.13919546]
# Optimal state trajectory: [-1.99466193 -1.99466231  0.15918987  0.15919546]
# Step 8: Optimization successful!
# Optimal cost: 11472.24023874664
# Optimal initial state trajectory: [-1.99466193 -1.99466231  0.15918987  0.15919546]
# Optimal state trajectory: [-1.99307004 -1.99307035  0.17918987  0.17919546]
# Step 9: Optimization successful!
# Optimal cost: 11466.031539054478
# Optimal initial state trajectory: [-1.99307004 -1.99307035  0.17918987  0.17919546]
# Optimal state trajectory: [-1.99127814 -1.9912784   0.19918987  0.19919546]
# Step 10: Optimization successful!
# Optimal cost: 11459.47250668374
# Optimal initial state trajectory: [-1.99127814 -1.9912784   0.19918987  0.19919546]
# Optimal state trajectory: [-1.98928624 -1.98928644  0.21918987  0.21919546]
# Step 11: Optimization successful!
# Optimal cost: 11452.56326729075
# Optimal initial state trajectory: [-1.98928624 -1.98928644  0.21918987  0.21919546]
# Optimal state trajectory: [-1.98709434 -1.98709449  0.23918987  0.23919546]
# Step 12: Optimization successful!
# Optimal cost: 11445.304180578449
# Optimal initial state trajectory: [-1.98709434 -1.98709449  0.23918987  0.23919546]
# Optimal state trajectory: [-1.98470244 -1.98470254  0.25918987  0.25919546]
# Step 13: Optimization successful!
# Optimal cost: 11437.695633421334
# Optimal initial state trajectory: [-1.98470244 -1.98470254  0.25918987  0.25919546]
# Optimal state trajectory: [-1.98211054 -1.98211058  0.27918987  0.27919546]
# Step 14: Optimization successful!
# Optimal cost: 11429.738031887231
# Optimal initial state trajectory: [-1.98211054 -1.98211058  0.27918987  0.27919546]
# Optimal state trajectory: [-1.97931864 -1.97931863  0.29918987  0.29919546]
# Step 15: Optimization successful!
# Optimal cost: 11421.431801237277
# Optimal initial state trajectory: [-1.97931864 -1.97931863  0.29918987  0.29919546]
# Optimal state trajectory: [-1.97632674 -1.97632667  0.31918987  0.31919546]
# Step 16: Optimization successful!
# Optimal cost: 11412.777385925969
# Optimal initial state trajectory: [-1.97632674 -1.97632667  0.31918987  0.31919546]
# Optimal state trajectory: [-1.97313485 -1.97313472  0.33918987  0.33919546]
# Step 17: Optimization successful!
# Optimal cost: 11403.775249601094
# Optimal initial state trajectory: [-1.97313485 -1.97313472  0.33918987  0.33919546]
# Optimal state trajectory: [-1.96974295 -1.96974276  0.35918987  0.35919546]
# Step 18: Optimization successful!
# Optimal cost: 11394.425875103809
# Optimal initial state trajectory: [-1.96974295 -1.96974276  0.35918987  0.35919546]
# Optimal state trajectory: [-1.96615105 -1.96615081  0.37918987  0.37919546]
# Step 19: Optimization successful!
# Optimal cost: 11384.729764468553
# Optimal initial state trajectory: [-1.96615105 -1.96615081  0.37918987  0.37919546]
# Optimal state trajectory: [-1.96235915 -1.96235885  0.39918987  0.39919546]
# Step 20: Optimization successful!
# Optimal cost: 11374.68743825807
# Optimal initial state trajectory: [-1.96235915 -1.96235885  0.39918987  0.39919546]
# Optimal state trajectory: [-1.95836725 -1.9583669   0.41918987  0.41919546]
# Step 21: Optimization successful!
# Optimal cost: 11364.299222916856
# Optimal initial state trajectory: [-1.95836725 -1.9583669   0.41918987  0.41919546]
# Optimal state trajectory: [-1.95417535 -1.95417494  0.43918987  0.43919546]
# Step 22: Optimization successful!
# Optimal cost: 11353.565506210216
# Optimal initial state trajectory: [-1.95417535 -1.95417494  0.43918987  0.43919546]
# Optimal state trajectory: [-1.94978345 -1.94978299  0.45918987  0.45919546]
# Step 23: Optimization successful!
# Optimal cost: 11342.486865259165
# Optimal initial state trajectory: [-1.94978345 -1.94978299  0.45918987  0.45919546]
# Optimal state trajectory: [-1.94519156 -1.94519103  0.47918987  0.47919546]
# Step 24: Optimization successful!
# Optimal cost: 11331.063896375566
# Optimal initial state trajectory: [-1.94519156 -1.94519103  0.47918987  0.47919546]
# Optimal state trajectory: [-1.94039966 -1.94039908  0.49918987  0.49919546]
# Step 25: Optimization successful!
# Optimal cost: 11319.297215062175
# Optimal initial state trajectory: [-1.94039966 -1.94039908  0.49918987  0.49919546]
# Optimal state trajectory: [-1.93540776 -1.93540713  0.51918987  0.51919546]
# Step 26: Optimization successful!
# Optimal cost: 11307.187456012622
# Optimal initial state trajectory: [-1.93540776 -1.93540713  0.51918987  0.51919546]
# Optimal state trajectory: [-1.93021586 -1.93021517  0.53918987  0.53919546]
# Step 27: Optimization successful!
# Optimal cost: 11294.735273111388
# Optimal initial state trajectory: [-1.93021586 -1.93021517  0.53918987  0.53919546]
# Optimal state trajectory: [-1.92482396 -1.92482322  0.55918987  0.55919546]
# Step 28: Optimization successful!
# Optimal cost: 11281.94133943387
# Optimal initial state trajectory: [-1.92482396 -1.92482322  0.55918987  0.55919546]
# Optimal state trajectory: [-1.91923206 -1.91923126  0.57918987  0.57919546]
# Step 29: Optimization successful!
# Optimal cost: 11268.8063472463
# Optimal initial state trajectory: [-1.91923206 -1.91923126  0.57918987  0.57919546]
# Optimal state trajectory: [-1.91344016 -1.91343931  0.59918987  0.59919546]
# Step 30: Optimization successful!
# Optimal cost: 11255.331008005793
# Optimal initial state trajectory: [-1.91344016 -1.91343931  0.59918987  0.59919546]
# Optimal state trajectory: [-1.90744826 -1.90744735  0.61918987  0.61919546]
# Step 31: Optimization successful!
# Optimal cost: 11241.5158430371
# Optimal initial state trajectory: [-1.90744826 -1.90744735  0.61918987  0.61919546]
# Optimal state trajectory: [-1.90125637 -1.9012554   0.63918987  0.63919546]
# Step 32: Optimization successful!
# Optimal cost: 11227.368594260928
# Optimal initial state trajectory: [-1.90125637 -1.9012554   0.63918987  0.63919546]
# Optimal state trajectory: [-1.89486447 -1.89486344  0.65918987  0.65881004]
# Step 33: Optimization successful!
# Optimal cost: 11212.906647947279
# Optimal initial state trajectory: [-1.89486447 -1.89486344  0.65918987  0.65881004]
# Optimal state trajectory: [-1.88827257 -1.88827534  0.67918987  0.67796832]
# Step 34: Optimization successful!
# Optimal cost: 11198.135797123812
# Optimal initial state trajectory: [-1.88827257 -1.88827534  0.67918987  0.67796832]
# Optimal state trajectory: [-1.88148067 -1.88149566  0.69918987  0.69669789]
# Step 35: Optimization successful!
# Optimal cost: 11183.05916180786
# Optimal initial state trajectory: [-1.88148067 -1.88149566  0.69918987  0.69669789]
# Optimal state trajectory: [-1.87448877 -1.87452868  0.71918987  0.71499317]
# Step 36: Optimization successful!
# Optimal cost: 11167.680547307464
# Optimal initial state trajectory: [-1.87448877 -1.87452868  0.71918987  0.71499317]
# Optimal state trajectory: [-1.86729687 -1.86737875  0.73918987  0.73285973]
# Step 37: Optimization successful!
# Optimal cost: 11152.003638678103
# Optimal initial state trajectory: [-1.86729687 -1.86737875  0.73918987  0.73285973]
# Optimal state trajectory: [-1.85990497 -1.86005015  0.75918987  0.75029934]
# Step 38: Optimization successful!
# Optimal cost: 11136.032261718743
# Optimal initial state trajectory: [-1.85990497 -1.86005015  0.75918987  0.75029934]
# Optimal state trajectory: [-1.85231307 -1.85254716  0.77918987  0.76731503]
# Step 39: Optimization successful!
# Optimal cost: 11119.770189802524
# Optimal initial state trajectory: [-1.85231307 -1.85254716  0.77918987  0.76731503]
# Optimal state trajectory: [-1.84452118 -1.84487401  0.7990409   0.78398736]
# Step 40: Optimization successful!
# Optimal cost: 11103.224287943121
# Optimal initial state trajectory: [-1.84452118 -1.84487401  0.7990409   0.78398736]
# Optimal state trajectory: [-1.83653077 -1.83703413  0.81857037  0.80043392]
# Step 41: Optimization successful!
# Optimal cost: 11086.40186160288
# Optimal initial state trajectory: [-1.83653077 -1.83703413  0.81857037  0.80043392]
# Optimal state trajectory: [-1.82834506 -1.8290298   0.8377904   0.81667179]
# Step 42: Optimization successful!
# Optimal cost: 11069.306736383627
# Optimal initial state trajectory: [-1.82834506 -1.8290298   0.8377904   0.81667179]
# Optimal state trajectory: [-1.81996716 -1.82086308  0.85670139  0.83269576]
# Step 43: Optimization successful!
# Optimal cost: 11051.943518268841
# Optimal initial state trajectory: [-1.81996716 -1.82086308  0.85670139  0.83269576]
# Optimal state trajectory: [-1.81140015 -1.81253612  0.87530839  0.84850961]
# Step 44: Optimization successful!
# Optimal cost: 11034.316477220886
# Optimal initial state trajectory: [-1.81140015 -1.81253612  0.87530839  0.84850961]
# Optimal state trajectory: [-1.80264706 -1.80405102  0.8936145   0.86411344]
# Step 45: Optimization successful!
# Optimal cost: 11016.42999017648
# Optimal initial state trajectory: [-1.80264706 -1.80405102  0.8936145   0.86411344]
# Optimal state trajectory: [-1.79371092 -1.79540989  0.91162354  0.87950887]
# Step 46: Optimization successful!
# Optimal cost: 10998.28836357041
# Optimal initial state trajectory: [-1.79371092 -1.79540989  0.91162354  0.87950887]
# Optimal state trajectory: [-1.78459468 -1.7866148   0.92933896  0.89469687]
# Step 47: Optimization successful!
# Optimal cost: 10979.895904552972
# Optimal initial state trajectory: [-1.78459468 -1.7866148   0.92933896  0.89469687]
# Optimal state trajectory: [-1.77530129 -1.77766783  0.9467643   0.90967867]
# Step 48: Optimization successful!
# Optimal cost: 10961.256890391163
# Optimal initial state trajectory: [-1.77530129 -1.77766783  0.9467643   0.90967867]
# Optimal state trajectory: [-1.76583365 -1.76857105  0.96390298  0.9244554 ]
# Step 49: Optimization successful!
# Optimal cost: 10942.375580613183
# Optimal initial state trajectory: [-1.76583365 -1.76857105  0.96390298  0.9244554 ]
# Optimal state trajectory: [-1.75619462 -1.75932649  0.98075843  0.9390282 ]
# Step 50: Optimization successful!
# Optimal cost: 10923.256211088188
# Optimal initial state trajectory: [-1.75619462 -1.75932649  0.98075843  0.9390282 ]
# Optimal state trajectory: [-1.74638703 -1.74993621  0.99733398  0.9533982 ]
# Step 51: Optimization successful!
# Optimal cost: 10903.90299612109
# Optimal initial state trajectory: [-1.74638703 -1.74993621  0.99733398  0.9533982 ]
# Optimal state trajectory: [-1.73641369 -1.74040223  1.01363295  0.96756655]
# Step 52: Optimization successful!
# Optimal cost: 10884.320126897275
# Optimal initial state trajectory: [-1.73641369 -1.74040223  1.01363295  0.96756655]
# Optimal state trajectory: [-1.72627737 -1.73072656  1.0296586   0.98153437]
# Step 53: Optimization successful!
# Optimal cost: 10864.511771405205
# Optimal initial state trajectory: [-1.72627737 -1.73072656  1.0296586   0.98153437]
# Optimal state trajectory: [-1.71598078 -1.72091122  1.04541414  0.99530276]
# Step 54: Optimization successful!
# Optimal cost: 10844.482073911679
# Optimal initial state trajectory: [-1.71598078 -1.72091122  1.04541414  0.99530276]
# Optimal state trajectory: [-1.70552664 -1.71095819  1.06090276  1.00887286]
# Step 55: Optimization successful!
# Optimal cost: 10824.235154286253
# Optimal initial state trajectory: [-1.70552664 -1.71095819  1.06090276  1.00887286]
# Optimal state trajectory: [-1.69491761 -1.70086946  1.07612759  1.02224577]
# Step 56: Optimization successful!
# Optimal cost: 10803.775108511678
# Optimal initial state trajectory: [-1.69491761 -1.70086946  1.07612759  1.02224577]
# Optimal state trajectory: [-1.68415633 -1.690647    1.09109171  1.03542258]
# Step 57: Optimization successful!
# Optimal cost: 10783.106007434018
# Optimal initial state trajectory: [-1.68415633 -1.690647    1.09109171  1.03542258]
# Optimal state trajectory: [-1.67324542 -1.68029278  1.10579818  1.04840441]
# Step 58: Optimization successful!
# Optimal cost: 10762.231896538828
# Optimal initial state trajectory: [-1.67324542 -1.68029278  1.10579818  1.04840441]
# Optimal state trajectory: [-1.66218744 -1.66980873  1.12025001  1.06119236]
# Step 59: Optimization successful!
# Optimal cost: 10741.156795726774
# Optimal initial state trajectory: [-1.66218744 -1.66980873  1.12025001  1.06119236]
# Optimal state trajectory: [-1.65098494 -1.65919681  1.13445016  1.0737875 ]
# Step 60: Optimization successful!
# Optimal cost: 10719.884699529091
# Optimal initial state trajectory: [-1.65098494 -1.65919681  1.13445016  1.0737875 ]
# Optimal state trajectory: [-1.63964043 -1.64845894  1.14840157  1.08619094]
# Step 61: Optimization successful!
# Optimal cost: 10698.419576032815
# Optimal initial state trajectory: [-1.63964043 -1.64845894  1.14840157  1.08619094]
# Optimal state trajectory: [-1.62815642 -1.63759703  1.16210712  1.09840374]
# Step 62: Optimization successful!
# Optimal cost: 10676.765367012424
# Optimal initial state trajectory: [-1.62815642 -1.63759703  1.16210712  1.09840374]
# Optimal state trajectory: [-1.61653535 -1.62661299  1.17556968  1.110427  ]
# Step 63: Optimization successful!
# Optimal cost: 10654.925987582288
# Optimal initial state trajectory: [-1.61653535 -1.62661299  1.17556968  1.110427  ]
# Optimal state trajectory: [-1.60477965 -1.61550872  1.18879206  1.12226178]
# Step 64: Optimization successful!
# Optimal cost: 10632.905326085938
# Optimal initial state trajectory: [-1.60477965 -1.61550872  1.18879206  1.12226178]
# Optimal state trajectory: [-1.59289173 -1.6042861   1.20177704  1.13390916]
# Step 65: Optimization successful!
# Optimal cost: 10610.707243409815
# Optimal initial state trajectory: [-1.59289173 -1.6042861   1.20177704  1.13390916]
# Optimal state trajectory: [-1.58087396 -1.59294701  1.21452735  1.1453702 ]
# Step 66: Optimization successful!
# Optimal cost: 10588.33557345013
# Optimal initial state trajectory: [-1.58087396 -1.59294701  1.21452735  1.1453702 ]
# Optimal state trajectory: [-1.56872869 -1.58149331  1.22704572  1.15664596]
# Step 67: Optimization successful!
# Optimal cost: 10565.794122247811
# Optimal initial state trajectory: [-1.56872869 -1.58149331  1.22704572  1.15664596]
# Optimal state trajectory: [-1.55645823 -1.56992685  1.23933482  1.16773752]
# Step 68: Optimization successful!
# Optimal cost: 10543.086668047286
# Optimal initial state trajectory: [-1.55645823 -1.56992685  1.23933482  1.16773752]
# Optimal state trajectory: [-1.54406488 -1.55824947  1.25139729  1.17864591]
# Step 69: Optimization successful!
# Optimal cost: 10520.216961283793
# Optimal initial state trajectory: [-1.54406488 -1.55824947  1.25139729  1.17864591]
# Optimal state trajectory: [-1.53155091 -1.54646301  1.26323573  1.1893722 ]
# Step 70: Optimization successful!
# Optimal cost: 10497.188724199035
# Optimal initial state trajectory: [-1.53155091 -1.54646301  1.26323573  1.1893722 ]
# Optimal state trajectory: [-1.51891855 -1.53456929  1.27485272  1.19991744]
# Step 71: Optimization successful!
# Optimal cost: 10474.005650680374
# Optimal initial state trajectory: [-1.51891855 -1.53456929  1.27485272  1.19991744]
# Optimal state trajectory: [-1.50617002 -1.52257012  1.28625079  1.21028267]
# Step 72: Optimization successful!
# Optimal cost: 10450.67140643204
# Optimal initial state trajectory: [-1.50617002 -1.52257012  1.28625079  1.21028267]
# Optimal state trajectory: [-1.49330751 -1.51046729  1.29743246  1.22046893]
# Step 73: Optimization successful!
# Optimal cost: 10427.189628293347
# Optimal initial state trajectory: [-1.49330751 -1.51046729  1.29743246  1.22046893]
# Optimal state trajectory: [-1.48033319 -1.4982626   1.3084002   1.23047726]
# Step 74: Optimization successful!
# Optimal cost: 10403.563924460868
# Optimal initial state trajectory: [-1.48033319 -1.4982626   1.3084002   1.23047726]
# Optimal state trajectory: [-1.46724919 -1.48595783  1.31915647  1.2403087 ]
# Step 75: Optimization successful!
# Optimal cost: 10379.797874289681
# Optimal initial state trajectory: [-1.46724919 -1.48595783  1.31915647  1.2403087 ]
# Optimal state trajectory: [-1.45405762 -1.47355474  1.32970367  1.24996428]
# Step 76: Optimization successful!
# Optimal cost: 10355.89502816812
# Optimal initial state trajectory: [-1.45405762 -1.47355474  1.32970367  1.24996428]
# Optimal state trajectory: [-1.44076059 -1.4610551   1.34004419  1.25944504]
# Step 77: Optimization successful!
# Optimal cost: 10331.858907324142
# Optimal initial state trajectory: [-1.44076059 -1.4610551   1.34004419  1.25944504]
# Optimal state trajectory: [-1.42736014 -1.44846065  1.3501804   1.26875199]
# Step 78: Optimization successful!
# Optimal cost: 10307.693004155008
# Optimal initial state trajectory: [-1.42736014 -1.44846065  1.3501804   1.26875199]
# Optimal state trajectory: [-1.41385834 -1.43577313  1.3601146   1.27788616]
# Step 79: Optimization successful!
# Optimal cost: 10283.400781797165
# Optimal initial state trajectory: [-1.41385834 -1.43577313  1.3601146   1.27788616]
# Optimal state trajectory: [-1.40025719 -1.42299427  1.36984911  1.28684857]
# Step 80: Optimization successful!
# Optimal cost: 10258.985673942525
# Optimal initial state trajectory: [-1.40025719 -1.42299427  1.36984911  1.28684857]
# Optimal state trajectory: [-1.3865587  -1.41012578  1.3793862   1.29564024]
# Step 81: Optimization successful!
# Optimal cost: 10234.451085028153
# Optimal initial state trajectory: [-1.3865587  -1.41012578  1.3793862   1.29564024]
# Optimal state trajectory: [-1.37276484 -1.39716938  1.38872809  1.30426219]
# Step 82: Optimization successful!
# Optimal cost: 10209.800390097322
# Optimal initial state trajectory: [-1.37276484 -1.39716938  1.38872809  1.30426219]
# Optimal state trajectory: [-1.35887756 -1.38412676  1.39787702  1.31271541]
# Step 83: Optimization successful!
# Optimal cost: 10185.03693469093
# Optimal initial state trajectory: [-1.35887756 -1.38412676  1.39787702  1.31271541]
# Optimal state trajectory: [-1.34489879 -1.3709996   1.40683517  1.32100094]
# Step 84: Optimization successful!
# Optimal cost: 10160.164034793474
# Optimal initial state trajectory: [-1.34489879 -1.3709996   1.40683517  1.32100094]
# Optimal state trajectory: [-1.33083044 -1.35778959  1.4156047   1.32911975]
# Step 85: Optimization successful!
# Optimal cost: 10135.1849771445
# Optimal initial state trajectory: [-1.33083044 -1.35778959  1.4156047   1.32911975]
# Optimal state trajectory: [-1.31667439 -1.3444984   1.42418775  1.33707287]
# Step 86: Optimization successful!
# Optimal cost: 10110.103018793452
# Optimal initial state trajectory: [-1.31667439 -1.3444984   1.42418775  1.33707287]
# Optimal state trajectory: [-1.30243251 -1.33112767  1.43258642  1.34486129]
# Step 87: Optimization successful!
# Optimal cost: 10084.921387200535
# Optimal initial state trajectory: [-1.30243251 -1.33112767  1.43258642  1.34486129]
# Optimal state trajectory: [-1.28810665 -1.31767905  1.4408028   1.352486  ]
# Step 88: Optimization successful!
# Optimal cost: 10059.64328027807
# Optimal initial state trajectory: [-1.28810665 -1.31767905  1.4408028   1.352486  ]
# Optimal state trajectory: [-1.27369862 -1.30415419  1.44883896  1.35994801]
# Step 89: Optimization successful!
# Optimal cost: 10034.271866363468
# Optimal initial state trajectory: [-1.27369862 -1.30415419  1.44883896  1.35994801]
# Optimal state trajectory: [-1.25921023 -1.29055471  1.45669691  1.36724829]
# Step 90: Optimization successful!
# Optimal cost: 10008.810284334522
# Optimal initial state trajectory: [-1.25921023 -1.29055471  1.45669691  1.36724829]
# Optimal state trajectory: [-1.24464326 -1.27688223  1.46437869  1.37438785]
# Step 91: Optimization successful!
# Optimal cost: 9983.261643478982
# Optimal initial state trajectory: [-1.24464326 -1.27688223  1.46437869  1.37438785]
# Optimal state trajectory: [-1.22999948 -1.26313835  1.47188626  1.38136766]
# Step 92: Optimization successful!
# Optimal cost: 9957.629023508316
# Optimal initial state trajectory: [-1.22999948 -1.26313835  1.47188626  1.38136766]
# Optimal state trajectory: [-1.21528061 -1.24932468  1.47922161  1.3881887 ]
# Step 93: Optimization successful!
# Optimal cost: 9931.915474764553
# Optimal initial state trajectory: [-1.21528061 -1.24932468  1.47922161  1.3881887 ]
# Optimal state trajectory: [-1.2004884  -1.23544279  1.48638665  1.39485197]
# Step 94: Optimization successful!
# Optimal cost: 9906.124017967688
# Optimal initial state trajectory: [-1.2004884  -1.23544279  1.48638665  1.39485197]
# Optimal state trajectory: [-1.18562453 -1.22149427  1.49338333  1.40135842]
# Step 95: Optimization successful!
# Optimal cost: 9880.257644420491
# Optimal initial state trajectory: [-1.18562453 -1.22149427  1.49338333  1.40135842]
# Optimal state trajectory: [-1.1706907  -1.20748068  1.50021352  1.40770904]
# Step 96: Optimization successful!
# Optimal cost: 9854.319316093995
# Optimal initial state trajectory: [-1.1706907  -1.20748068  1.50021352  1.40770904]
# Optimal state trajectory: [-1.15568856 -1.19340359  1.5068791   1.4139048 ]
# Step 97: Optimization successful!
# Optimal cost: 9828.311965671735
# Optimal initial state trajectory: [-1.15568856 -1.19340359  1.5068791   1.4139048 ]
# Optimal state trajectory: [-1.14061977 -1.17926455  1.51338193  1.41994666]
# Step 98: Optimization successful!
# Optimal cost: 9802.238496486176
# Optimal initial state trajectory: [-1.14061977 -1.17926455  1.51338193  1.41994666]
# Optimal state trajectory: [-1.12548595 -1.16506508  1.51972382  1.42583558]
# Step 99: Optimization successful!
# Optimal cost: 9776.101782587755
# Optimal initial state trajectory: [-1.12548595 -1.16506508  1.51972382  1.42583558]
# Optimal state trajectory: [-1.11028871 -1.15080672  1.5259066   1.43157254]
# Step 100: Optimization successful!
# Optimal cost: 9749.904668844081
# Optimal initial state trajectory: [-1.11028871 -1.15080672  1.5259066   1.43157254]
# Optimal state trajectory: [-1.09502965 -1.136491    1.53193205  1.43715849]
# Step 101: Optimization successful!
# Optimal cost: 9723.64997111603
# Optimal initial state trajectory: [-1.09502965 -1.136491    1.53193205  1.43715849]
# Optimal state trajectory: [-1.07971033 -1.12211941  1.53780193  1.44259438]
# Step 102: Optimization successful!
# Optimal cost: 9697.340476162091
# Optimal initial state trajectory: [-1.07971033 -1.12211941  1.53780193  1.44259438]
# Optimal state trajectory: [-1.06433231 -1.10769347  1.54351799  1.44788117]
# Step 103: Optimization successful!
# Optimal cost: 9670.978941765808
# Optimal initial state trajectory: [-1.06433231 -1.10769347  1.54351799  1.44788117]
# Optimal state trajectory: [-1.04889713 -1.09321466  1.54908196  1.4530198 ]
# Step 104: Optimization successful!
# Optimal cost: 9644.568096821287
# Optimal initial state trajectory: [-1.04889713 -1.09321466  1.54908196  1.4530198 ]
# Optimal state trajectory: [-1.03340631 -1.07868446  1.55449555  1.45801123]
# Step 105: Optimization successful!
# Optimal cost: 9618.110641416393
# Optimal initial state trajectory: [-1.03340631 -1.07868446  1.55449555  1.45801123]
# Optimal state trajectory: [-1.01786135 -1.06410435  1.55976044  1.46285641]
# Step 106: Optimization successful!
# Optimal cost: 9591.609247034317
# Optimal initial state trajectory: [-1.01786135 -1.06410435  1.55976044  1.46285641]
# Optimal state trajectory: [-1.00226375 -1.04947578  1.5648783   1.46755626]
# Step 107: Optimization successful!
# Optimal cost: 9565.066556488226
# Optimal initial state trajectory: [-1.00226375 -1.04947578  1.5648783   1.46755626]
# Optimal state trajectory: [-0.98661497 -1.03480022  1.56985078  1.47211173]
# Step 108: Optimization successful!
# Optimal cost: 9538.485184034818
# Optimal initial state trajectory: [-0.98661497 -1.03480022  1.56985078  1.47211173]
# Optimal state trajectory: [-0.97091646 -1.0200791   1.57467952  1.47652375]
# Step 109: Optimization successful!
# Optimal cost: 9511.867715547634
# Optimal initial state trajectory: [-0.97091646 -1.0200791   1.57467952  1.47652375]
# Optimal state trajectory: [-0.95516966 -1.00531387  1.57936612  1.48079326]
# Step 110: Optimization successful!
# Optimal cost: 9485.21670859267
# Optimal initial state trajectory: [-0.95516966 -1.00531387  1.57936612  1.48079326]
# Optimal state trajectory: [-0.939376   -0.99050593  1.58391218  1.48492118]
# Step 111: Optimization successful!
# Optimal cost: 9458.53469252779
# Optimal initial state trajectory: [-0.939376   -0.99050593  1.58391218  1.48492118]
# Optimal state trajectory: [-0.92353688 -0.97565672  1.58831927  1.48890844]
# Step 112: Optimization successful!
# Optimal cost: 9431.824168609632
# Optimal initial state trajectory: [-0.92353688 -0.97565672  1.58831927  1.48890844]
# Optimal state trajectory: [-0.90765369 -0.96076764  1.59258896  1.49275597]
# Step 113: Optimization successful!
# Optimal cost: 9405.087610203587
# Optimal initial state trajectory: [-0.90765369 -0.96076764  1.59258896  1.49275597]
# Optimal state trajectory: [-0.8917278  -0.94584008  1.59672279  1.49646467]
# Step 114: Optimization successful!
# Optimal cost: 9378.327462646806
# Optimal initial state trajectory: [-0.8917278  -0.94584008  1.59672279  1.49646467]
# Optimal state trajectory: [-0.87576057 -0.93087543  1.60072228  1.50003547]
# Step 115: Optimization successful!
# Optimal cost: 9351.546143614753
# Optimal initial state trajectory: [-0.87576057 -0.93087543  1.60072228  1.50003547]
# Optimal state trajectory: [-0.85975335 -0.91587508  1.60458893  1.50346928]
# Step 116: Optimization successful!
# Optimal cost: 9324.746043172807
# Optimal initial state trajectory: [-0.85975335 -0.91587508  1.60458893  1.50346928]
# Optimal state trajectory: [-0.84370746 -0.90084038  1.60832425  1.50676702]
# Step 117: Optimization successful!
# Optimal cost: 9297.929523903413
# Optimal initial state trajectory: [-0.84370746 -0.90084038  1.60832425  1.50676702]
# Optimal state trajectory: [-0.82762422 -0.88577271  1.61192971  1.50992958]
# Step 118: Optimization successful!
# Optimal cost: 9271.098921009934
# Optimal initial state trajectory: [-0.82762422 -0.88577271  1.61192971  1.50992958]
# Optimal state trajectory: [-0.81150492 -0.87067342  1.61540676  1.51295788]
# Step 119: Optimization successful!
# Optimal cost: 9244.256542493576
# Optimal initial state trajectory: [-0.81150492 -0.87067342  1.61540676  1.51295788]
# Optimal state trajectory: [-0.79535085 -0.85554384  1.61875685  1.5158528 ]
# Step 120: Optimization successful!
# Optimal cost: 9217.404669131183
# Optimal initial state trajectory: [-0.79535085 -0.85554384  1.61875685  1.5158528 ]
# Optimal state trajectory: [-0.77916328 -0.84038531  1.62198141  1.51861526]
# Step 121: Optimization successful!
# Optimal cost: 9190.545555003986
# Optimal initial state trajectory: [-0.77916328 -0.84038531  1.62198141  1.51861526]
# Optimal state trajectory: [-0.76294347 -0.82519916  1.62508184  1.52124613]
# Step 122: Optimization successful!
# Optimal cost: 9163.681427940655
# Optimal initial state trajectory: [-0.76294347 -0.82519916  1.62508184  1.52124613]
# Optimal state trajectory: [-0.74669265 -0.8099867   1.62805955  1.52374632]
# Step 123: Optimization successful!
# Optimal cost: 9136.81449530446
# Optimal initial state trajectory: [-0.74669265 -0.8099867   1.62805955  1.52374632]
# Optimal state trajectory: [-0.73041205 -0.79474923  1.63091591  1.52611671]
# Step 124: Optimization successful!
# Optimal cost: 9109.946932779842
# Optimal initial state trajectory: [-0.73041205 -0.79474923  1.63091591  1.52611671]
# Optimal state trajectory: [-0.71410289 -0.77948807  1.63365229  1.52835819]
# Step 125: Optimization successful!
# Optimal cost: 9083.080888309962
# Optimal initial state trajectory: [-0.71410289 -0.77948807  1.63365229  1.52835819]
# Optimal state trajectory: [-0.69776637 -0.76420448  1.63627005  1.53047162]
# Step 126: Optimization successful!
# Optimal cost: 9056.218483602614
# Optimal initial state trajectory: [-0.69776637 -0.76420448  1.63627005  1.53047162]
# Optimal state trajectory: [-0.68140367 -0.74889977  1.63877052  1.5324579 ]
# Step 127: Optimization successful!
# Optimal cost: 9029.361814280592
# Optimal initial state trajectory: [-0.68140367 -0.74889977  1.63877052  1.5324579 ]
# Optimal state trajectory: [-0.66501597 -0.73357519  1.64115503  1.5343179 ]
# Step 128: Optimization successful!
# Optimal cost: 9002.512950074879
# Optimal initial state trajectory: [-0.66501597 -0.73357519  1.64115503  1.5343179 ]
# Optimal state trajectory: [-0.64860442 -0.71823201  1.64342488  1.53605247]
# Step 129: Optimization successful!
# Optimal cost: 8975.673934901499
# Optimal initial state trajectory: [-0.64860442 -0.71823201  1.64342488  1.53605247]
# Optimal state trajectory: [-0.63217017 -0.70287149  1.64558137  1.5376625 ]
# Step 130: Optimization successful!
# Optimal cost: 8948.846786986103
# Optimal initial state trajectory: [-0.63217017 -0.70287149  1.64558137  1.5376625 ]
# Optimal state trajectory: [-0.61571435 -0.68749486  1.64762578  1.53914884]
# Step 131: Optimization successful!
# Optimal cost: 8922.033499086732
# Optimal initial state trajectory: [-0.61571435 -0.68749486  1.64762578  1.53914884]
# Optimal state trajectory: [-0.5992381  -0.67210337  1.64955939  1.54051236]
# Step 132: Optimization successful!
# Optimal cost: 8895.236038894074
# Optimal initial state trajectory: [-0.5992381  -0.67210337  1.64955939  1.54051236]
# Optimal state trajectory: [-0.5827425  -0.65669825  1.65138344  1.5417539 ]
# Step 133: Optimization successful!
# Optimal cost: 8868.456348546653
# Optimal initial state trajectory: [-0.5827425  -0.65669825  1.65138344  1.5417539 ]
# Optimal state trajectory: [-0.56622867 -0.64128071  1.65309918  1.54287433]
# Step 134: Optimization successful!
# Optimal cost: 8841.696345402874
# Optimal initial state trajectory: [-0.56622867 -0.64128071  1.65309918  1.54287433]
# Optimal state trajectory: [-0.54969768 -0.62585197  1.65470784  1.54387448]
# Step 135: Optimization successful!
# Optimal cost: 8814.957922043879
# Optimal initial state trajectory: [-0.54969768 -0.62585197  1.65470784  1.54387448]
# Optimal state trajectory: [-0.5331506  -0.61041322  1.65621063  1.54475522]
# Step 136: Optimization successful!
# Optimal cost: 8788.242946280317
# Optimal initial state trajectory: [-0.5331506  -0.61041322  1.65621063  1.54475522]
# Optimal state trajectory: [-0.51658849 -0.59496567  1.65760877  1.54551737]
# Step 137: Optimization successful!
# Optimal cost: 8761.553261333858
# Optimal initial state trajectory: [-0.51658849 -0.59496567  1.65760877  1.54551737]
# Optimal state trajectory: [-0.5000124  -0.5795105   1.65890344  1.54616178]
# Step 138: Optimization successful!
# Optimal cost: 8734.890686373945
# Optimal initial state trajectory: [-0.5000124  -0.5795105   1.65890344  1.54616178]
# Optimal state trajectory: [-0.48342337 -0.56404888  1.66009582  1.54668927]
# Step 139: Optimization successful!
# Optimal cost: 8708.257016090105
# Optimal initial state trajectory: [-0.48342337 -0.56404888  1.66009582  1.54668927]
# Optimal state trajectory: [-0.46682241 -0.54858199  1.66118707  1.54710069]
# Step 140: Optimization successful!
# Optimal cost: 8681.654021350932
# Optimal initial state trajectory: [-0.46682241 -0.54858199  1.66118707  1.54710069]
# Optimal state trajectory: [-0.45021054 -0.53311098  1.66217837  1.54739685]
# Step 141: Optimization successful!
# Optimal cost: 8655.08344924735
# Optimal initial state trajectory: [-0.45021054 -0.53311098  1.66217837  1.54739685]
# Optimal state trajectory: [-0.43358876 -0.51763701  1.66307084  1.54757859]
# Step 142: Optimization successful!
# Optimal cost: 8628.547022897998
# Optimal initial state trajectory: [-0.43358876 -0.51763701  1.66307084  1.54757859]
# Optimal state trajectory: [-0.41695805 -0.50216122  1.66386563  1.54764671]
# Step 143: Optimization successful!
# Optimal cost: 8602.046442330791
# Optimal initial state trajectory: [-0.41695805 -0.50216122  1.66386563  1.54764671]
# Optimal state trajectory: [-0.40031939 -0.48668476  1.66456385  1.54760204]
# Step 144: Optimization successful!
# Optimal cost: 8575.583383937581
# Optimal initial state trajectory: [-0.40031939 -0.48668476  1.66456385  1.54760204]
# Optimal state trajectory: [-0.38367375 -0.47120874  1.66516662  1.54744539]
# Step 145: Optimization successful!
# Optimal cost: 8549.159501070217
# Optimal initial state trajectory: [-0.38367375 -0.47120874  1.66516662  1.54744539]
# Optimal state trajectory: [-0.36702209 -0.45573428  1.66567503  1.54717756]
# Step 146: Optimization successful!
# Optimal cost: 8522.77642432903
# Optimal initial state trajectory: [-0.36702209 -0.45573428  1.66567503  1.54717756]
# Optimal state trajectory: [-0.35036534 -0.44026251  1.66609018  1.54679936]
# Step 147: Optimization successful!
# Optimal cost: 8496.43576101371
# Optimal initial state trajectory: [-0.35036534 -0.44026251  1.66609018  1.54679936]
# Optimal state trajectory: [-0.33370443 -0.42479451  1.66641314  1.54631159]
# Step 148: Optimization successful!
# Optimal cost: 8470.139096431603
# Optimal initial state trajectory: [-0.33370443 -0.42479451  1.66641314  1.54631159]
# Optimal state trajectory: [-0.3170403  -0.4093314   1.66664497  1.54571504]
# Step 149: Optimization successful!
# Optimal cost: 8443.887992755575
# Optimal initial state trajectory: [-0.3170403  -0.4093314   1.66664497  1.54571504]
# Optimal state trajectory: [-0.30037385 -0.39387425  1.66678675  1.54501052]
# Step 150: Optimization successful!
# Optimal cost: 8417.684001866835
# Optimal initial state trajectory: [-0.30037385 -0.39387425  1.66678675  1.54501052]
# Optimal state trajectory: [-0.28370599 -0.37842414  1.66683951  1.5441988 ]
# Step 151: Optimization successful!
# Optimal cost: 8391.52865231666
# Optimal initial state trajectory: [-0.28370599 -0.37842414  1.66683951  1.5441988 ]
# Optimal state trajectory: [-0.26703759 -0.36298215  1.66680429  1.54328067]
# Step 152: Optimization successful!
# Optimal cost: 8365.423441021292
# Optimal initial state trajectory: [-0.26703759 -0.36298215  1.66680429  1.54328067]
# Optimal state trajectory: [-0.25036955 -0.34754935  1.66668212  1.54225691]
# Step 153: Optimization successful!
# Optimal cost: 8339.369842724604
# Optimal initial state trajectory: [-0.25036955 -0.34754935  1.66668212  1.54225691]
# Optimal state trajectory: [-0.23370273 -0.33212678  1.66647402  1.5411283 ]
# Step 154: Optimization successful!
# Optimal cost: 8313.36931103337
# Optimal initial state trajectory: [-0.23370273 -0.33212678  1.66647402  1.5411283 ]
# Optimal state trajectory: [-0.21703799 -0.3167155   1.66618099  1.53989561]
# Step 155: Optimization successful!
# Optimal cost: 8287.42327802788
# Optimal initial state trajectory: [-0.21703799 -0.3167155   1.66618099  1.53989561]
# Optimal state trajectory: [-0.20037618 -0.30131654  1.66580403  1.5385596 ]
# Step 156: Optimization successful!
# Optimal cost: 8261.533154512843
# Optimal initial state trajectory: [-0.20037618 -0.30131654  1.66580403  1.5385596 ]
# Optimal state trajectory: [-0.18371814 -0.28593094  1.66534414  1.53712106]
# Step 157: Optimization successful!
# Optimal cost: 8235.700330184578
# Optimal initial state trajectory: [-0.18371814 -0.28593094  1.66534414  1.53712106]
# Optimal state trajectory: [-0.1670647  -0.27055973  1.66480229  1.53558072]
# Step 158: Optimization successful!
# Optimal cost: 8209.926174270551
# Optimal initial state trajectory: [-0.1670647  -0.27055973  1.66480229  1.53558072]
# Optimal state trajectory: [-0.15041667 -0.25520393  1.66417946  1.53393936]
# Step 159: Optimization successful!
# Optimal cost: 8184.212034635025
# Optimal initial state trajectory: [-0.15041667 -0.25520393  1.66417946  1.53393936]
# Optimal state trajectory: [-0.13377488 -0.23986453  1.6634766   1.53219771]
# Step 160: Optimization successful!
# Optimal cost: 8158.559239475438
# Optimal initial state trajectory: [-0.13377488 -0.23986453  1.6634766   1.53219771]
# Optimal state trajectory: [-0.11714011 -0.22454255  1.66269467  1.53035654]
# Step 161: Optimization successful!
# Optimal cost: 8132.969107343698
# Optimal initial state trajectory: [-0.11714011 -0.22454255  1.66269467  1.53035654]
# Optimal state trajectory: [-0.10051317 -0.20923899  1.66183463  1.52841658]
# Step 162: Optimization successful!
# Optimal cost: 8107.442945257703
# Optimal initial state trajectory: [-0.10051317 -0.20923899  1.66183463  1.52841658]
# Optimal state trajectory: [-0.08389482 -0.19395482  1.66089739  1.52637858]
# Step 163: Optimization successful!
# Optimal cost: 8081.9820200922495
# Optimal initial state trajectory: [-0.08389482 -0.19395482  1.66089739  1.52637858]
# Optimal state trajectory: [-0.06728585 -0.17869104  1.6598839   1.52424326]
# Step 164: Optimization successful!
# Optimal cost: 8056.58757880605
# Optimal initial state trajectory: [-0.06728585 -0.17869104  1.6598839   1.52424326]
# Optimal state trajectory: [-0.05068701 -0.16344861  1.65879507  1.52201137]
# Step 165: Optimization successful!
# Optimal cost: 8031.260848671419
# Optimal initial state trajectory: [-0.05068701 -0.16344861  1.65879507  1.52201137]
# Optimal state trajectory: [-0.03409906 -0.14822849  1.65763181  1.51968362]
# Step 166: Optimization successful!
# Optimal cost: 8006.003037226638
# Optimal initial state trajectory: [-0.03409906 -0.14822849  1.65763181  1.51968362]
# Optimal state trajectory: [-0.01752274 -0.13303166  1.65639504  1.51726075]
# Step 167: Optimization successful!
# Optimal cost: 7980.815344582921
# Optimal initial state trajectory: [-0.01752274 -0.13303166  1.65639504  1.51726075]
# Optimal state trajectory: [-9.58786955e-04 -1.17859048e-01  1.65508564e+00  1.51474346e+00]
# Step 168: Optimization successful!
# Optimal cost: 7955.69895840142
# Optimal initial state trajectory: [-9.58786955e-04 -1.17859048e-01  1.65508564e+00  1.51474346e+00]
# Optimal state trajectory: [ 0.01559207 -0.10271161  1.65370451  1.51213248]
# Step 169: Optimization successful!
# Optimal cost: 7930.65503063833
# Optimal initial state trajectory: [ 0.01559207 -0.10271161  1.65370451  1.51213248]
# Optimal state trajectory: [ 0.03212911 -0.08759029  1.65225253  1.50942852]
# Step 170: Optimization successful!
# Optimal cost: 7905.684693061395
# Optimal initial state trajectory: [ 0.03212911 -0.08759029  1.65225253  1.50942852]
# Optimal state trajectory: [ 0.04865164 -0.072496    1.65073058  1.50663227]
# Step 171: Optimization successful!
# Optimal cost: 7880.789059682814
# Optimal initial state trajectory: [ 0.04865164 -0.072496    1.65073058  1.50663227]
# Optimal state trajectory: [ 0.06515895 -0.05742968  1.64913952  1.50374446]
# Step 172: Optimization successful!
# Optimal cost: 7855.969226118551
# Optimal initial state trajectory: [ 0.06515895 -0.05742968  1.64913952  1.50374446]
# Optimal state trajectory: [ 0.08165034 -0.04239224  1.64748022  1.50076576]
# Step 173: Optimization successful!
# Optimal cost: 7831.226269493875
# Optimal initial state trajectory: [ 0.08165034 -0.04239224  1.64748022  1.50076576]
# Optimal state trajectory: [ 0.09812514 -0.02738458  1.64575352  1.49769687]
# Step 174: Optimization successful!
# Optimal cost: 7806.5612485145975
# Optimal initial state trajectory: [ 0.09812514 -0.02738458  1.64575352  1.49769687]
# Optimal state trajectory: [ 0.11458268 -0.01240761  1.64396028  1.49453849]
# Step 175: Optimization successful!
# Optimal cost: 7781.975209924248
# Optimal initial state trajectory: [ 0.11458268 -0.01240761  1.64396028  1.49453849]
# Optimal state trajectory: [0.13102228 0.00253778 1.64210134 1.4912913 ]
# Step 176: Optimization successful!
# Optimal cost: 7757.469196766285
# Optimal initial state trajectory: [0.13102228 0.00253778 1.64210134 1.4912913 ]
# Optimal state trajectory: [0.14744329 0.01745069 1.64017753 1.48795597]
# Step 177: Optimization successful!
# Optimal cost: 7733.044217723324
# Optimal initial state trajectory: [0.14744329 0.01745069 1.64017753 1.48795597]
# Optimal state trajectory: [0.16384507 0.03233025 1.63818968 1.48453319]
# Step 178: Optimization successful!
# Optimal cost: 7708.701260344959
# Optimal initial state trajectory: [0.16384507 0.03233025 1.63818968 1.48453319]
# Optimal state trajectory: [0.18022697 0.04717558 1.63613861 1.48102363]
# Step 179: Optimization successful!
# Optimal cost: 7684.441296931371
# Optimal initial state trajectory: [0.18022697 0.04717558 1.63613861 1.48102363]
# Optimal state trajectory: [0.19658835 0.06198582 1.63402515 1.47742795]
# Step 180: Optimization successful!
# Optimal cost: 7660.265302045225
# Optimal initial state trajectory: [0.19658835 0.06198582 1.63402515 1.47742795]
# Optimal state trajectory: [0.2129286  0.0767601  1.63185009 1.47374682]
# Step 181: Optimization successful!
# Optimal cost: 7636.174227776287
# Optimal initial state trajectory: [0.2129286  0.0767601  1.63185009 1.47374682]
# Optimal state trajectory: [0.22924711 0.09149756 1.62961424 1.4699809 ]
# Step 182: Optimization successful!
# Optimal cost: 7612.168994732052
# Optimal initial state trajectory: [0.22924711 0.09149756 1.62961424 1.4699809 ]
# Optimal state trajectory: [0.24554325 0.10619737 1.62731841 1.46613084]
# Step 183: Optimization successful!
# Optimal cost: 7588.250508111964
# Optimal initial state trajectory: [0.24554325 0.10619737 1.62731841 1.46613084]
# Optimal state trajectory: [0.26181643 0.12085868 1.62496339 1.46219729]
# Step 184: Optimization successful!
# Optimal cost: 7564.419655861338
# Optimal initial state trajectory: [0.26181643 0.12085868 1.62496339 1.46219729]
# Optimal state trajectory: [0.27806607 0.13548065 1.62254996 1.4581809 ]
# Step 185: Optimization successful!
# Optimal cost: 7540.677309971711
# Optimal initial state trajectory: [0.27806607 0.13548065 1.62254996 1.4581809 ]
# Optimal state trajectory: [0.29429157 0.15006246 1.6200789  1.45408231]
# Step 186: Optimization successful!
# Optimal cost: 7517.024327113555
# Optimal initial state trajectory: [0.29429157 0.15006246 1.6200789  1.45408231]
# Optimal state trajectory: [0.31049235 0.16460329 1.61755101 1.44990216]
# Step 187: Optimization successful!
# Optimal cost: 7493.461547183326
# Optimal initial state trajectory: [0.31049235 0.16460329 1.61755101 1.44990216]
# Optimal state trajectory: [0.32666786 0.17910231 1.61496704 1.44564108]
# Step 188: Optimization successful!
# Optimal cost: 7469.989809911141
# Optimal initial state trajectory: [0.32666786 0.17910231 1.61496704 1.44564108]
# Optimal state trajectory: [0.34281753 0.19355872 1.61232777 1.4412997 ]
# Step 189: Optimization successful!
# Optimal cost: 7446.609935016664
# Optimal initial state trajectory: [0.34281753 0.19355872 1.61232777 1.4412997 ]
# Optimal state trajectory: [0.35894081 0.20797172 1.60963397 1.43687865]
# Step 190: Optimization successful!
# Optimal cost: 7423.3227386546505
# Optimal initial state trajectory: [0.35894081 0.20797172 1.60963397 1.43687865]
# Optimal state trajectory: [0.37503715 0.2223405  1.60688638 1.43237854]
# Step 191: Optimization successful!
# Optimal cost: 7400.129014763388
# Optimal initial state trajectory: [0.37503715 0.2223405  1.60688638 1.43237854]
# Optimal state trajectory: [0.39110602 0.23666429 1.60408577 1.42779999]
# Step 192: Optimization successful!
# Optimal cost: 7377.029526386782
# Optimal initial state trajectory: [0.39110602 0.23666429 1.60408577 1.42779999]
# Optimal state trajectory: [0.40714687 0.25094229 1.6012329  1.42314361]
# Step 193: Optimization successful!
# Optimal cost: 7354.025022475618
# Optimal initial state trajectory: [0.40714687 0.25094229 1.6012329  1.42314361]
# Optimal state trajectory: [0.4231592  0.26517372 1.59832849 1.41841002]
# Step 194: Optimization successful!
# Optimal cost: 7331.116236860837
# Optimal initial state trajectory: [0.4231592  0.26517372 1.59832849 1.41841002]
# Optimal state trajectory: [0.43914249 0.27935782 1.5953733  1.41359982]
# Step 195: Optimization successful!
# Optimal cost: 7308.30388892869
# Optimal initial state trajectory: [0.43914249 0.27935782 1.5953733  1.41359982]
# Optimal state trajectory: [0.45509622 0.29349382 1.59236808 1.4087136 ]
# Step 196: Optimization successful!
# Optimal cost: 7285.588683979093
# Optimal initial state trajectory: [0.45509622 0.29349382 1.59236808 1.4087136 ]
# Optimal state trajectory: [0.4710199  0.30758096 1.58931354 1.40375196]
# Step 197: Optimization successful!
# Optimal cost: 7262.9713727191065
# Optimal initial state trajectory: [0.47101989 0.30758096 1.5893135  1.40375192]
# Optimal state trajectory: [0.48691302 0.32161847 1.58620919 1.39871597]
# Step 198: Optimization successful!
# Optimal cost: 7240.452492214522
# Optimal initial state trajectory: [0.48691302 0.32161847 1.58620919 1.39871597]
# Optimal state trajectory: [0.50277512 0.33560563 1.58305832 1.3936054 ]
# Step 199: Optimization successful!
# Optimal cost: 7218.0329370166755
# Optimal initial state trajectory: [0.50277512 0.33560563 1.58305832 1.3936054 ]
# Optimal state trajectory: [0.5186057  0.34954169 1.57986024 1.38842097]
# Step 200: Optimization successful!
# Optimal cost: 7195.713236345923
# Optimal initial state trajectory: [0.5186057  0.34954169 1.57986024 1.38842097]
# Optimal state trajectory: [0.5344043  0.3634259  1.5766158  1.38316354]
# Step 201: Optimization successful!
# Optimal cost: 7173.494070533716
# Optimal initial state trajectory: [0.5344043  0.3634259  1.5766158  1.38316354]
# Optimal state trajectory: [0.55017046 0.37725753 1.57332567 1.37783358]
# Step 202: Optimization successful!
# Optimal cost: 7151.376042814666
# Optimal initial state trajectory: [0.55017046 0.37725753 1.57332567 1.37783358]
# Optimal state trajectory: [0.56590372 0.39103587 1.56999058 1.3724317 ]
# Step 203: Optimization successful!
# Optimal cost: 7129.35984398678
# Optimal initial state trajectory: [0.56590371 0.39103586 1.56999055 1.37243161]
# Optimal state trajectory: [0.58160361 0.40476017 1.56661095 1.36695838]
# Step 204: Optimization successful!
# Optimal cost: 7107.445876591024
# Optimal initial state trajectory: [0.58160361 0.40476017 1.56661095 1.36695838]
# Optimal state trajectory: [0.59726972 0.41842975 1.56318811 1.36141436]
# Step 205: Optimization successful!
# Optimal cost: 7085.634950465824
# Optimal initial state trajectory: [0.59726972 0.41842975 1.56318811 1.36141436]
# Optimal state trajectory: [0.6129016  0.4320439  1.55972242 1.35580006]
# Step 206: Optimization successful!
# Optimal cost: 7063.927578740721
# Optimal initial state trajectory: [0.6129016  0.4320439  1.55972242 1.35580006]
# Optimal state trajectory: [0.62849883 0.4456019  1.55621463 1.35011608]
# Step 207: Optimization successful!
# Optimal cost: 7042.32432989544
# Optimal initial state trajectory: [0.62849883 0.4456019  1.55621463 1.35011608]
# Optimal state trajectory: [0.64406097 0.45910306 1.55266542 1.34436297]
# Step 208: Optimization successful!
# Optimal cost: 7020.825746487996
# Optimal initial state trajectory: [0.64406097 0.45910306 1.55266542 1.34436297]
# Optimal state trajectory: [0.65958763 0.47254669 1.54907552 1.33854127]
# Step 209: Optimization successful!
# Optimal cost: 6999.432389800208
# Optimal initial state trajectory: [0.65958763 0.47254669 1.54907552 1.33854127]
# Optimal state trajectory: [0.67507838 0.4859321  1.54544561 1.33265152]
# Step 210: Optimization successful!
# Optimal cost: 6978.144795290836
# Optimal initial state trajectory: [0.67507838 0.4859321  1.54544561 1.33265152]
# Optimal state trajectory: [0.69053284 0.49925862 1.54177641 1.32669428]
# Step 211: Optimization successful!
# Optimal cost: 6956.96348988262
# Optimal initial state trajectory: [0.69053284 0.49925862 1.54177641 1.32669428]
# Optimal state trajectory: [0.7059506  0.51252556 1.5380686  1.32067007]
# Step 212: Optimization successful!
# Optimal cost: 6935.889013794546
# Optimal initial state trajectory: [0.7059506  0.51252556 1.53806859 1.32067006]
# ...
# Step 926: Optimization successful!
# Optimal cost: 889.2518802807082
# Optimal initial state trajectory: [7.6656728  5.85457043 0.4806377  0.84980237]
# Optimal state trajectory: [7.67047917 5.86306846 0.47964157 0.84809785]
# Step 927: Optimization successful!
# Optimal cost: 885.6059420686963
# Optimal initial state trajectory: [7.67047917 5.86306846 0.47964157 0.84809785]
# Optimal state trajectory: [7.67527559 5.87154944 0.4786476  0.84639618]
# Step 928: Optimization successful!
# Optimal cost: 881.9748414987515
# Optimal initial state trajectory: [7.67527559 5.87154944 0.4786476  0.84639618]
# Optimal state trajectory: [7.68006207 5.8800134  0.47765578 0.84469735]
# Step 929: Optimization successful!
# Optimal cost: 878.3585200931515
# Optimal initial state trajectory: [7.68006207 5.8800134  0.47765578 0.84469735]
# Optimal state trajectory: [7.68483862 5.88846037 0.47666612 0.84300139]
# Step 930: Optimization successful!
# Optimal cost: 874.7569195716268
# Optimal initial state trajectory: [7.68483862 5.88846037 0.47666612 0.84300139]
# Optimal state trajectory: [7.68960529 5.89689039 0.4756786  0.84130828]
# Step 931: Optimization successful!
# Optimal cost: 871.1699818512877
# Optimal initial state trajectory: [7.68960529 5.89689039 0.4756786  0.84130828]
# Optimal state trajectory: [7.69436207 5.90530347 0.47469322 0.83961803]
# Step 932: Optimization successful!
# Optimal cost: 867.5976490465282
# Optimal initial state trajectory: [7.69436207 5.90530347 0.47469322 0.83961803]
# Optimal state trajectory: [7.699109   5.91369965 0.47370997 0.83793065]
# Step 933: Optimization successful!
# Optimal cost: 864.0398634689287
# Optimal initial state trajectory: [7.699109   5.91369965 0.47370997 0.83793065]
# Optimal state trajectory: [7.7038461  5.92207896 0.47272885 0.83624614]
# Step 934: Optimization successful!
# Optimal cost: 860.4965676271429
# Optimal initial state trajectory: [7.7038461  5.92207896 0.47272885 0.83624614]
# Optimal state trajectory: [7.70857339 5.93044142 0.47174985 0.83456451]
# Step 935: Optimization successful!
# Optimal cost: 856.96770422677
# Optimal initial state trajectory: [7.70857339 5.93044142 0.47174985 0.83456451]
# Optimal state trajectory: [7.71329089 5.93878706 0.47077296 0.83288575]
# Step 936: Optimization successful!
# Optimal cost: 853.4532161702225
# Optimal initial state trajectory: [7.71329089 5.93878706 0.47077296 0.83288575]
# Optimal state trajectory: [7.71799862 5.94711592 0.46979818 0.83120986]
# Step 937: Optimization successful!
# Optimal cost: 849.9530465565783
# Optimal initial state trajectory: [7.71799862 5.94711592 0.46979818 0.83120986]
# Optimal state trajectory: [7.7226966  5.95542802 0.46882551 0.82953686]
# Step 938: Optimization successful!
# Optimal cost: 846.4671386814204
# Optimal initial state trajectory: [7.7226966  5.95542802 0.46882551 0.82953686]
# Optimal state trajectory: [7.72738486 5.96372339 0.46785493 0.82786675]
# Step 939: Optimization successful!
# Optimal cost: 842.9954360366734
# Optimal initial state trajectory: [7.72738486 5.96372339 0.46785493 0.82786675]
# Optimal state trajectory: [7.73206341 5.97200205 0.46688645 0.82619952]
# Step 940: Optimization successful!
# Optimal cost: 839.5378823104224
# Optimal initial state trajectory: [7.73206341 5.97200205 0.46688645 0.82619952]
# Optimal state trajectory: [7.73673227 5.98026405 0.46592005 0.82453518]
# Step 941: Optimization successful!
# Optimal cost: 836.0944213867257
# Optimal initial state trajectory: [7.73673227 5.98026405 0.46592005 0.82453518]
# Optimal state trajectory: [7.74139147 5.9885094  0.46495573 0.82287373]
# Step 942: Optimization successful!
# Optimal cost: 832.6649973454173
# Optimal initial state trajectory: [7.74139147 5.9885094  0.46495573 0.82287373]
# Optimal state trajectory: [7.74604103 5.99673814 0.46399348 0.82121517]
# Step 943: Optimization successful!
# Optimal cost: 829.2495544618978
# Optimal initial state trajectory: [7.74604103 5.99673814 0.46399348 0.82121517]
# Optimal state trajectory: [7.75068096 6.00495029 0.4630333  0.81955951]
# Step 944: Optimization successful!
# Optimal cost: 825.8480372069187
# Optimal initial state trajectory: [7.75068096 6.00495029 0.4630333  0.81955951]
# Optimal state trajectory: [7.7553113  6.01314589 0.46207519 0.81790675]
# Step 945: Optimization successful!
# Optimal cost: 822.4603902463577
# Optimal initial state trajectory: [7.7553113  6.01314589 0.46207519 0.81790675]
# Optimal state trajectory: [7.75993205 6.02132495 0.46111913 0.81625689]
# Step 946: Optimization successful!
# Optimal cost: 819.0865584409789
# Optimal initial state trajectory: [7.75993205 6.02132495 0.46111913 0.81625689]
# Optimal state trajectory: [7.76454324 6.02948752 0.46016513 0.81460992]
# Step 947: Optimization successful!
# Optimal cost: 815.7264868461971
# Optimal initial state trajectory: [7.76454324 6.02948752 0.46016513 0.81460992]
# Optimal state trajectory: [7.76914489 6.03763362 0.45921317 0.81296586]
# Step 948: Optimization successful!
# Optimal cost: 812.3801207118164
# Optimal initial state trajectory: [7.76914489 6.03763362 0.45921317 0.81296586]
# Optimal state trajectory: [7.77373702 6.04576328 0.45826325 0.81132471]
# Step 949: Optimization successful!
# Optimal cost: 809.0474054817765
# Optimal initial state trajectory: [7.77373702 6.04576328 0.45826325 0.81132471]
# Optimal state trajectory: [7.77831966 6.05387653 0.45731537 0.80968646]
# Step 950: Optimization successful!
# Optimal cost: 805.7282867938808
# Optimal initial state trajectory: [7.77831966 6.05387653 0.45731537 0.80968646]
# Optimal state trajectory: [7.78289281 6.06197339 0.45636952 0.80805111]
# Step 951: Optimization successful!
# Optimal cost: 802.4227104795214
# Optimal initial state trajectory: [7.78289281 6.06197339 0.45636952 0.80805111]
# Optimal state trajectory: [7.7874565  6.0700539  0.45542569 0.80641867]
# Step 952: Optimization successful!
# Optimal cost: 799.1306225633942
# Optimal initial state trajectory: [7.7874565  6.0700539  0.45542569 0.80641867]
# Optimal state trajectory: [7.79201076 6.07811809 0.45448388 0.80478914]
# Step 953: Optimization successful!
# Optimal cost: 795.8519692632055
# Optimal initial state trajectory: [7.79201076 6.07811809 0.45448388 0.80478914]
# Optimal state trajectory: [7.7965556  6.08616598 0.45354408 0.80316252]
# Step 954: Optimization successful!
# Optimal cost: 792.5866969893758
# Optimal initial state trajectory: [7.7965556  6.08616598 0.45354408 0.80316252]
# Optimal state trajectory: [7.80109104 6.09419761 0.4526063  0.80153881]
# Step 955: Optimization successful!
# Optimal cost: 789.3347523447278
# Optimal initial state trajectory: [7.80109104 6.09419761 0.4526063  0.80153881]
# Optimal state trajectory: [7.8056171  6.10221299 0.45167052 0.79991801]
# Step 956: Optimization successful!
# Optimal cost: 786.0960821241811
# Optimal initial state trajectory: [7.8056171  6.10221299 0.45167052 0.79991801]
# Optimal state trajectory: [7.81013381 6.11021217 0.45073673 0.79830012]
# Step 957: Optimization successful!
# Optimal cost: 782.8706333144238
# Optimal initial state trajectory: [7.81013381 6.11021217 0.45073673 0.79830012]
# Optimal state trajectory: [7.81464118 6.11819518 0.44980494 0.79668514]
# Step 958: Optimization successful!
# Optimal cost: 779.6583530935889
# Optimal initial state trajectory: [7.81464118 6.11819518 0.44980494 0.79668514]
# Optimal state trajectory: [7.81913923 6.12616203 0.44887513 0.79507307]
# Step 959: Optimization successful!
# Optimal cost: 776.45918883092
# Optimal initial state trajectory: [7.81913923 6.12616203 0.44887513 0.79507307]
# Optimal state trajectory: [7.82362798 6.13411276 0.44794731 0.79346392]
# Step 960: Optimization successful!
# Optimal cost: 773.2730880864332
# Optimal initial state trajectory: [7.82362798 6.13411276 0.44794731 0.79346392]
# Optimal state trajectory: [7.82810745 6.1420474  0.44702147 0.79185768]
# Step 961: Optimization successful!
# Optimal cost: 770.099998610567
# Optimal initial state trajectory: [7.82810745 6.1420474  0.44702147 0.79185768]
# Optimal state trajectory: [7.83257766 6.14996597 0.4460976  0.79025435]
# Step 962: Optimization successful!
# Optimal cost: 766.9398683438325
# Optimal initial state trajectory: [7.83257766 6.14996597 0.4460976  0.79025435]
# Optimal state trajectory: [7.83703864 6.15786852 0.44517569 0.78865393]
# Step 963: Optimization successful!
# Optimal cost: 763.7926454164538
# Optimal initial state trajectory: [7.83703864 6.15786852 0.44517569 0.78865393]
# Optimal state trajectory: [7.8414904  6.16575506 0.44425575 0.78705642]
# Step 964: Optimization successful!
# Optimal cost: 760.6582781480063
# Optimal initial state trajectory: [7.8414904  6.16575506 0.44425575 0.78705642]
# Optimal state trajectory: [7.84593295 6.17362562 0.44333776 0.78546182]
# Step 965: Optimization successful!
# Optimal cost: 757.5367150470436
# Optimal initial state trajectory: [7.84593295 6.17362562 0.44333776 0.78546182]
# Optimal state trajectory: [7.85036633 6.18148024 0.44242173 0.78387014]
# Step 966: Optimization successful!
# Optimal cost: 754.4279048107239
# Optimal initial state trajectory: [7.85036633 6.18148024 0.44242173 0.78387014]
# Optimal state trajectory: [7.85479055 6.18931894 0.44150764 0.78228137]
# Step 967: Optimization successful!
# Optimal cost: 751.3317963244309
# Optimal initial state trajectory: [7.85479055 6.18931894 0.44150764 0.78228137]
# Optimal state trajectory: [7.85920563 6.19714175 0.4405955  0.78069551]
# Step 968: Optimization successful!
# Optimal cost: 748.2483386613864
# Optimal initial state trajectory: [7.85920563 6.19714175 0.4405955  0.78069551]
# Optimal state trajectory: [7.86361158 6.20494871 0.43968529 0.77911255]
# Step 969: Optimization successful!
# Optimal cost: 745.1774810822595
# Optimal initial state trajectory: [7.86361158 6.20494871 0.43968529 0.77911255]
# Optimal state trajectory: [7.86800843 6.21273983 0.43877701 0.77753251]
# Step 970: Optimization successful!
# Optimal cost: 742.1191730347722
# Optimal initial state trajectory: [7.86800843 6.21273983 0.43877701 0.77753251]
# Optimal state trajectory: [7.8723962  6.22051516 0.43787067 0.77595538]
# Step 971: Optimization successful!
# Optimal cost: 739.0733641532959
# Optimal initial state trajectory: [7.8723962  6.22051516 0.43787067 0.77595538]
# Optimal state trajectory: [7.87677491 6.22827471 0.43696624 0.77438115]
# Step 972: Optimization successful!
# Optimal cost: 736.0400042584537
# Optimal initial state trajectory: [7.87677491 6.22827471 0.43696624 0.77438115]
# Optimal state trajectory: [7.88114457 6.23601852 0.43606373 0.77280983]
# Step 973: Optimization successful!
# Optimal cost: 733.0190433566995
# Optimal initial state trajectory: [7.88114457 6.23601852 0.43606373 0.77280983]
# Optimal state trajectory: [7.88550521 6.24374662 0.43516314 0.77124141]
# Step 974: Optimization successful!
# Optimal cost: 730.010431639915
# Optimal initial state trajectory: [7.88550521 6.24374662 0.43516314 0.77124141]
# Optimal state trajectory: [7.88985684 6.25145904 0.43426445 0.76967591]
# Step 975: Optimization successful!
# Optimal cost: 727.014119484983
# Optimal initial state trajectory: [7.88985684 6.25145904 0.43426445 0.76967591]
# Optimal state trajectory: [7.89419949 6.2591558  0.43336767 0.7681133 ]
# Step 976: Optimization successful!
# Optimal cost: 724.0300574533702
# Optimal initial state trajectory: [7.89419949 6.2591558  0.43336767 0.7681133 ]
# Optimal state trajectory: [7.89853316 6.26683693 0.43247278 0.7665536 ]
# Step 977: Optimization successful!
# Optimal cost: 721.0581962906992
# Optimal initial state trajectory: [7.89853316 6.26683693 0.43247278 0.7665536 ]
# Optimal state trajectory: [7.90285789 6.27450246 0.43157979 0.7649968 ]
# Step 978: Optimization successful!
# Optimal cost: 718.0984869263165
# Optimal initial state trajectory: [7.90285789 6.27450246 0.43157979 0.7649968 ]
# Optimal state trajectory: [7.90717369 6.28215243 0.43068869 0.7634429 ]
# Step 979: Optimization successful!
# Optimal cost: 715.1508804728588
# Optimal initial state trajectory: [7.90717369 6.28215243 0.43068869 0.7634429 ]
# Optimal state trajectory: [7.91148058 6.28978686 0.42979947 0.76189189]
# Step 980: Optimization successful!
# Optimal cost: 712.2153282258166
# Optimal initial state trajectory: [7.91148058 6.28978686 0.42979947 0.76189189]
# Optimal state trajectory: [7.91577857 6.29740578 0.42891213 0.76034379]
# Step 981: Optimization successful!
# Optimal cost: 709.2917816630919
# Optimal initial state trajectory: [7.91577857 6.29740578 0.42891213 0.76034379]
# Optimal state trajectory: [7.92006769 6.30500922 0.42802667 0.75879858]
# Step 982: Optimization successful!
# Optimal cost: 706.3801924445515
# Optimal initial state trajectory: [7.92006769 6.30500922 0.42802667 0.75879858]
# Optimal state trajectory: [7.92434796 6.3125972  0.42714308 0.75725626]
# Step 983: Optimization successful!
# Optimal cost: 703.4805124115794
# Optimal initial state trajectory: [7.92434796 6.3125972  0.42714308 0.75725626]
# Optimal state trajectory: [7.92861939 6.32016977 0.42626135 0.75571684]
# Step 984: Optimization successful!
# Optimal cost: 700.5926935866265
# Optimal initial state trajectory: [7.92861939 6.32016977 0.42626135 0.75571684]
# Optimal state trajectory: [7.932882   6.32772694 0.42538148 0.75418031]
# Step 985: Optimization successful!
# Optimal cost: 697.7166881727532
# Optimal initial state trajectory: [7.932882   6.32772694 0.42538148 0.75418031]
# Optimal state trajectory: [7.93713582 6.33526874 0.42450348 0.75264667]
# Step 986: Optimization successful!
# Optimal cost: 694.8524485531733
# Optimal initial state trajectory: [7.93713582 6.33526874 0.42450348 0.75264667]
# Optimal state trajectory: [7.94138085 6.34279521 0.42362732 0.75111591]
# Step 987: Optimization successful!
# Optimal cost: 691.9999272907918
# Optimal initial state trajectory: [7.94138085 6.34279521 0.42362732 0.75111591]
# Optimal state trajectory: [7.94561713 6.35030636 0.42275301 0.74958804]
# Step 988: Optimization successful!
# Optimal cost: 689.159077127742
# Optimal initial state trajectory: [7.94561713 6.35030636 0.42275301 0.74958804]
# Optimal state trajectory: [7.94984466 6.35780224 0.42188055 0.74806305]
# Step 989: Optimization successful!
# Optimal cost: 686.3298509849162
# Optimal initial state trajectory: [7.94984466 6.35780224 0.42188055 0.74806305]
# Optimal state trajectory: [7.95406346 6.36528288 0.42100992 0.74654095]
# Step 990: Optimization successful!
# Optimal cost: 683.5122019615006
# Optimal initial state trajectory: [7.95406346 6.36528288 0.42100992 0.74654095]
# Optimal state trajectory: [7.95827356 6.37274828 0.42014113 0.74502172]
# Step 991: Optimization successful!
# Optimal cost: 680.7060833344988
# Optimal initial state trajectory: [7.95827356 6.37274828 0.42014113 0.74502172]
# Optimal state trajectory: [7.96247497 6.3801985  0.41927417 0.74350537]
# Step 992: Optimization successful!
# Optimal cost: 677.9114485582611
# Optimal initial state trajectory: [7.96247497 6.3801985  0.41927417 0.74350537]
# Optimal state trajectory: [7.96666771 6.38763356 0.41840903 0.7419919 ]
# Step 993: Optimization successful!
# Optimal cost: 675.1282512640038
# Optimal initial state trajectory: [7.96666771 6.38763356 0.41840903 0.7419919 ]
# Optimal state trajectory: [7.9708518  6.39505347 0.41754571 0.7404813 ]
# Step 994: Optimization successful!
# Optimal cost: 672.3564452593317
# Optimal initial state trajectory: [7.9708518  6.39505347 0.41754571 0.7404813 ]
# Optimal state trajectory: [7.97502726 6.40245829 0.41668422 0.73897357]
# Step 995: Optimization successful!
# Optimal cost: 669.5959845277582
# Optimal initial state trajectory: [7.97502726 6.40245829 0.41668422 0.73897357]
# Optimal state trajectory: [7.9791941  6.40984802 0.41582453 0.7374687 ]
# Step 996: Optimization successful!
# Optimal cost: 666.8468232282171
# Optimal initial state trajectory: [7.9791941  6.40984802 0.41582453 0.7374687 ]
# Optimal state trajectory: [7.98335235 6.41722271 0.41496665 0.73596671]
# Step 997: Optimization successful!
# Optimal cost: 664.1089156945812
# Optimal initial state trajectory: [7.98335235 6.41722271 0.41496665 0.73596671]
# Optimal state trajectory: [7.98750201 6.42458238 0.41411058 0.73446758]
# Step 998: Optimization successful!
# Optimal cost: 661.38221643517
# Optimal initial state trajectory: [7.98750201 6.42458238 0.41411058 0.73446758]
# Optimal state trajectory: [7.99164312 6.43192705 0.4132563  0.7329713 ]
# plotting
